# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Citeseer Dataset

# %%
GCN_256 = np.load('./citeseer/GCN_accuracy_list_citeseer.npy')
GCN_random_03 = np.load('./citeseer/GCN_accuracy_list_citeseer_random_ratio0.03.npy')
GCN_laplacian_03 = np.load('./citeseer/GCN_accuracy_list_citeseer_laplacian_ratio0.03.npy')
GCN_degree_03 = np.load('./citeseer/GCN_accuracy_list_citeseer_degree_ratio0.03.npy')
GCN_kmedoid_03 = np.load('./citeseer/GCN_accuracy_list_citeseer_Kmedoid_ncluster54_PropToSdFalse_AggregateLayer2_ratio0.03.npy')
GCN_Grain_ball_03 = np.load('./citeseer/GCN_accuracy_list_citeseer_GRAIN_ball_ratio0.03.npy')
GCN_Grain_NND_03 = np.load('./citeseer/GCN_accuracy_list_citeseer_GRAIN_NND_ratio0.03.npy')

citeseer_acc_256 = np.max(GCN_256)
citeseer_random_acc_03 = np.max(GCN_random_03)
citeseer_degree_acc_03 = np.max(GCN_degree_03)
citeseer_laplacian_acc_03 = np.max(GCN_laplacian_03) 
citeseer_kmedoid_acc_03 = np.max(GCN_kmedoid_03)
citeseer_batch_at_scale_acc_03 = citeseer_kmedoid_acc_03
citeseer_batch_at_scale_embed_acc_03 = citeseer_kmedoid_acc_03
citeseer_Grain_ball_acc_03 = np.max(GCN_Grain_ball_03)
citeseer_Grain_NND_acc_03 = np.max(GCN_Grain_NND_03)


GCN_random_05 = np.load('./citeseer/GCN_accuracy_list_citeseer_random_ratio0.05.npy')
GCN_laplacian_05 = np.load('./citeseer/GCN_accuracy_list_citeseer_laplacian_ratio0.05.npy')
GCN_degree_05 = np.load('./citeseer/GCN_accuracy_list_citeseer_degree_ratio0.05.npy')
GCN_kmedoid_05 = np.load('./citeseer/GCN_accuracy_list_citeseer_Kmedoid_ncluster91_PropToSdFalse_AggregateLayer2_ratio0.05.npy')
GCN_batch_at_scale_05 = np.load('./citeseer/GCN_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
GCN_batch_at_scale_embed_05 = np.load('./citeseer/GCN_accuracy_list_citeseer_batch_at_scale_embed_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
GCN_Grain_ball_05 = np.load('./citeseer/GCN_accuracy_list_citeseer_GRAIN_ball_ratio0.05.npy')
GCN_Grain_NND_05 = np.load('./citeseer/GCN_accuracy_list_citeseer_GRAIN_NND_ratio0.05.npy')

citeseer_random_acc_05 = np.max(GCN_random_05)
citeseer_degree_acc_05 = np.max(GCN_degree_05)
citeseer_laplacian_acc_05 = np.max(GCN_laplacian_05) 
citeseer_kmedoid_acc_05 = np.max(GCN_kmedoid_05)
citeseer_batch_at_scale_acc_05 = np.max(GCN_batch_at_scale_05)
citeseer_batch_at_scale_embed_acc_05 = np.max(GCN_batch_at_scale_embed_05)
citeseer_Grain_ball_acc_05 = np.max(GCN_Grain_ball_05)
citeseer_Grain_NND_acc_05 = np.max(GCN_Grain_NND_05)


GCN_random_10 = np.load('./citeseer/GCN_accuracy_list_citeseer_random_ratio0.1.npy')
GCN_laplacian_10 = np.load('./citeseer/GCN_accuracy_list_citeseer_laplacian_ratio0.1.npy')
GCN_degree_10 = np.load('./citeseer/GCN_accuracy_list_citeseer_degree_ratio0.1.npy')
GCN_kmedoid_10 = np.load('./citeseer/GCN_accuracy_list_citeseer_Kmedoid_ncluster182_PropToSdFalse_AggregateLayer2_ratio0.1.npy')
GCN_batch_at_scale_10 = np.load('./citeseer/GCN_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.1.npy')
GCN_batch_at_scale_embed_10 = np.load('./citeseer/GCN_accuracy_list_citeseer_batch_at_scale_embed_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.1.npy')
GCN_Grain_ball_10 = np.load('./citeseer/GCN_accuracy_list_citeseer_GRAIN_ball_ratio0.1.npy')
GCN_Grain_NND_10 = np.load('./citeseer/GCN_accuracy_list_citeseer_GRAIN_NND_ratio0.1.npy')

citeseer_random_acc_10 = np.max(GCN_random_10)
citeseer_degree_acc_10 = np.max(GCN_degree_10)
citeseer_laplacian_acc_10 = np.max(GCN_laplacian_10) 
citeseer_kmedoid_acc_10 = np.max(GCN_kmedoid_10)
citeseer_batch_at_scale_acc_10 = np.max(GCN_batch_at_scale_10)
citeseer_batch_at_scale_embed_acc_10 = np.max(GCN_batch_at_scale_embed_10)
citeseer_Grain_ball_acc_10 = np.max(GCN_Grain_ball_10)
citeseer_Grain_NND_acc_10 = np.max(GCN_Grain_NND_10)

# %%
row_1 = np.array([citeseer_acc_256, citeseer_random_acc_03, citeseer_degree_acc_03, citeseer_laplacian_acc_03, 
                  citeseer_kmedoid_acc_03, citeseer_Grain_ball_acc_03, citeseer_Grain_NND_acc_03,
                  citeseer_batch_at_scale_acc_03, citeseer_batch_at_scale_embed_acc_03])
row_2 = np.array([citeseer_acc_256, citeseer_random_acc_05, citeseer_degree_acc_05, citeseer_laplacian_acc_05, 
                  citeseer_kmedoid_acc_05, citeseer_Grain_ball_acc_05, citeseer_Grain_NND_acc_05,
                  citeseer_batch_at_scale_acc_05, citeseer_batch_at_scale_embed_acc_05])
row_3 = np.array([citeseer_acc_256, citeseer_random_acc_10, citeseer_degree_acc_10, citeseer_laplacian_acc_10, 
                  citeseer_kmedoid_acc_10, citeseer_Grain_ball_acc_10, citeseer_Grain_NND_acc_10,
                  citeseer_batch_at_scale_acc_10, citeseer_batch_at_scale_embed_acc_10])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["citeseer, ratio=0.03", "citeseer, ratio=0.05", "citeseer, ratio=0.1"]
names = ["Standard", "Random", "Degree", "Laplacian", "FeatProp (2-layer)", "Grain_ball", "Grain_NND", 
         "GIDUS", "GIDUS+Cluster_embed"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
# Out:
#                       Standard  Random  Degree  Laplacian  FeatProp (2-layer)  \
# citeseer, ratio=0.03     0.776   0.579   0.511      0.521               0.577
# citeseer, ratio=0.05     0.776   0.682   0.503      0.709               0.586
# citeseer, ratio=0.1      0.776   0.735   0.691      0.723               0.684
#
#                       Grain_ball  Grain_NND  GIDUS  GIDUS+Cluster_embed
# citeseer, ratio=0.03       0.680      0.675  0.577                0.577
# citeseer, ratio=0.05       0.712      0.708  0.724                0.729
# citeseer, ratio=0.1        0.730      0.728  0.742                0.746

# %% [markdown]
# ## Cora Dataset

# %%
GCN_256 = np.load('./cora/GCN_accuracy_list_cora.npy')
GCN_random_03 = np.load('./cora/GCN_accuracy_list_cora_random_ratio0.03.npy')
GCN_degree_03 = np.load('./cora/GCN_accuracy_list_cora_degree_ratio0.03.npy')
GCN_laplacian_03 = np.load('./cora/GCN_accuracy_list_cora_laplacian_ratio0.03.npy')
GCN_kmedoid_03 = np.load('./cora/GCN_accuracy_list_cora_Kmedoid_ncluster36_PropToSdFalse_AggregateLayer2_ratio0.03.npy')
GCN_Grain_ball_03 = np.load('./cora/GCN_accuracy_list_cora_GRAIN_ball_ratio0.03.npy')
GCN_Grain_NND_03 = np.load('./cora/GCN_accuracy_list_cora_GRAIN_NND_ratio0.03.npy')


cora_acc_256 = np.max(GCN_256)
cora_random_acc_03 = np.max(GCN_random_03)
cora_degree_acc_03 = np.max(GCN_degree_03)
cora_laplacian_acc_03 = np.max(GCN_laplacian_03) 
cora_kmedoid_acc_03 = np.max(GCN_kmedoid_03)
cora_Grain_ball_03 = np.max(GCN_Grain_ball_03)
cora_Grain_NND_03 = np.max(GCN_Grain_NND_03)
cora_batch_at_scale_acc_03 = cora_kmedoid_acc_03
cora_batch_at_scale_embed_acc_03 = cora_kmedoid_acc_03


GCN_random_05 = np.load('./cora/GCN_accuracy_list_cora_random_ratio0.05.npy')
GCN_degree_05 = np.load('./cora/GCN_accuracy_list_cora_degree_ratio0.05.npy')
GCN_laplacian_05 = np.load('./cora/GCN_accuracy_list_cora_laplacian_ratio0.05.npy')
GCN_kmedoid_05 = np.load('./cora/GCN_accuracy_list_cora_Kmedoid_ncluster60_PropToSdFalse_AggregateLayer2_ratio0.05.npy')
GCN_batch_at_scale_05 = np.load('./cora/GCN_accuracy_list_cora_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy') 
GCN_Grain_ball_05 = np.load('./cora/GCN_accuracy_list_cora_GRAIN_ball_ratio0.05.npy')
GCN_Grain_NND_05 = np.load('./cora/GCN_accuracy_list_cora_GRAIN_NND_ratio0.05.npy')
GCN_batch_at_scale_embed_05 = np.load('./cora/GCN_accuracy_list_cora_batch_at_scale_embed_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')

cora_random_acc_05 = np.max(GCN_random_05)
cora_degree_acc_05 = np.max(GCN_degree_05)
cora_laplacian_acc_05 = np.max(GCN_laplacian_05) 
cora_kmedoid_acc_05 = np.max(GCN_kmedoid_05)
cora_batch_at_scale_acc_05 = np.max(GCN_batch_at_scale_05)
cora_batch_at_scale_embed_acc_05 = np.max(GCN_batch_at_scale_embed_05)
cora_Grain_ball_05 = np.max(GCN_Grain_ball_05)
cora_Grain_NND_05 = np.max(GCN_Grain_NND_05)



GCN_random_10 = np.load('./cora/GCN_accuracy_list_cora_random_ratio0.1.npy')
GCN_degree_10 = np.load('./cora/GCN_accuracy_list_cora_degree_ratio0.1.npy')
GCN_laplacian_10 = np.load('./cora/GCN_accuracy_list_cora_laplacian_ratio0.1.npy')
GCN_kmedoid_10 = np.load('./cora/GCN_accuracy_list_cora_Kmedoid_ncluster120_PropToSdFalse_AggregateLayer2_ratio0.1.npy')
GCN_batch_at_scale_10 = np.load('./cora/GCN_accuracy_list_cora_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.1.npy') 
GCN_Grain_ball_10 = np.load('./cora/GCN_accuracy_list_cora_GRAIN_ball_ratio0.1.npy')
GCN_Grain_NND_10 = np.load('./cora/GCN_accuracy_list_cora_GRAIN_NND_ratio0.1.npy')
GCN_batch_at_scale_embed_10 = np.load('./cora/GCN_accuracy_list_cora_batch_at_scale_embed_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.1.npy')


cora_random_acc_10 = np.max(GCN_random_10)
cora_degree_acc_10 = np.max(GCN_degree_10)
cora_laplacian_acc_10 = np.max(GCN_laplacian_10) 
cora_kmedoid_acc_10 = np.max(GCN_kmedoid_10)
cora_batch_at_scale_acc_10 = np.max(GCN_batch_at_scale_10)
cora_batch_at_scale_embed_acc_10 = np.max(GCN_batch_at_scale_embed_10)
cora_Grain_ball_10 = np.max(GCN_Grain_ball_10)
cora_Grain_NND_10 = np.max(GCN_Grain_NND_10)

# %%
row_1 = np.array([cora_acc_256, cora_random_acc_03, cora_degree_acc_03, cora_laplacian_acc_03, cora_kmedoid_acc_03, 
                  cora_Grain_ball_03, cora_Grain_ball_03, cora_batch_at_scale_acc_03, cora_batch_at_scale_embed_acc_03])
row_2 = np.array([cora_acc_256, cora_random_acc_05, cora_degree_acc_05, cora_laplacian_acc_05, cora_kmedoid_acc_05, 
                  cora_Grain_ball_05, cora_Grain_ball_05,cora_batch_at_scale_acc_05, cora_batch_at_scale_embed_acc_05])
row_3 = np.array([cora_acc_256, cora_random_acc_10, cora_degree_acc_10, cora_laplacian_acc_10, cora_kmedoid_acc_10, 
                  cora_Grain_ball_10, cora_Grain_ball_10, cora_batch_at_scale_acc_10, cora_batch_at_scale_embed_acc_10])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["cora, ratio=0.03", "cora, ratio=0.05", "cora, ratio=0.1"]
names = ["Standard", "Random", "Degree", "Laplacian", "FeatProp (2-layer)", "Grain_ball", "Grain_NND", 
         "GIDUS", "GIDUS+Cluster_embed"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
# Out:
#                   Standard  Random  Degree  Laplacian  FeatProp (2-layer)  \
# cora, ratio=0.03     0.885   0.713   0.636      0.606               0.687
# cora, ratio=0.05     0.885   0.750   0.751      0.638               0.701
# cora, ratio=0.1      0.885   0.828   0.795      0.763               0.786
#
#                   Grain_ball  Grain_NND  GIDUS  GIDUS+Cluster_embed
# cora, ratio=0.03       0.747      0.747  0.687                0.687
# cora, ratio=0.05       0.778      0.778  0.813                0.796
# cora, ratio=0.1        0.808      0.808  0.856                0.829

# %%
acc_list = [cora_batch_at_scale_r1_acc_10, cora_batch_at_scale_r5_acc_10, cora_batch_at_scale_r10_acc_10,
           cora_batch_at_scale_acc_10]
plt.plot(["r=1", "r=5", "r=10", "r=20"], acc_list)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.xlabel("Sampling Redundancy, Km/Kt", fontsize =14)
plt.ylabel("Accuracy", fontsize =14)
plt.show()

# %%
row_1 = np.array([cora_batch_at_scale_acc_05, cora_batch_at_scale_random_acc_05, cora_batch_at_scale_round_robin_acc_05])
row_2 = np.array([cora_batch_at_scale_r10_acc_10, cora_batch_at_scale_random_acc_10, cora_batch_at_scale_round_robin_acc_10])
row_3 = np.array([cora_batch_at_scale_acc_15, cora_batch_at_scale_random_acc_15, cora_batch_at_scale_round_robin_acc_15])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["cora, ratio=0.05", "cora, ratio=0.1", "cora, ratio=0.15"]
names = ["Kmeans", "Random", "Round-Robin"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
# Out:
#                   Kmeans  Random  Round-Robin
# cora, ratio=0.05   0.753   0.748        0.752
# cora, ratio=0.1    0.805   0.786        0.795
# cora, ratio=0.15   0.837   0.818        0.821

# %% [markdown]
# ## Pubmed Dataset

# %%
GCN_256 = np.load('./pubmed/GCN_accuracy_list_pubmed.npy')
GCN_random_01 = np.load('./pubmed/GCN_accuracy_list_pubmed_random_ratio0.01.npy')
GCN_degree_01 = np.load('./pubmed/GCN_accuracy_list_pubmed_degree_ratio0.01.npy')
GCN_laplacian_01 = np.load('./pubmed/GCN_accuracy_list_pubmed_laplacian_ratio0.01.npy')
GCN_kmedoid_01 = np.load('./pubmed/GCN_accuracy_list_pubmed_Kmedoid_ncluster182_PropToSdFalse_AggregateLayer2_ratio0.01.npy')
GCN_Grain_ball_01 = np.load('./pubmed/GCN_accuracy_list_pubmed_GRAIN_ball_ratio0.01.npy')
GCN_Grain_NND_01 = np.load('./pubmed/GCN_accuracy_list_pubmed_GRAIN_NND_ratio0.01.npy')

pubmed_acc_256 = np.max(GCN_256)
pubmed_random_acc_01 = np.max(GCN_random_01)
pubmed_degree_acc_01 = np.max(GCN_degree_01)
pubmed_laplacian_acc_01 = np.max(GCN_laplacian_01) 
pubmed_kmedoid_acc_01 = np.max(GCN_kmedoid_01)
pubmed_batch_at_scale_acc_01 = pubmed_kmedoid_acc_01
pubmed_batch_at_scale_embed_acc_01 = pubmed_kmedoid_acc_01
pubmed_Grain_ball_acc_01 = np.max(GCN_Grain_ball_01)
pubmed_Grain_NND_acc_01 = np.max(GCN_Grain_NND_01)

GCN_random_03 = np.load('./pubmed/GCN_accuracy_list_pubmed_random_ratio0.03.npy')
GCN_degree_03 = np.load('./pubmed/GCN_accuracy_list_pubmed_degree_ratio0.03.npy')
GCN_laplacian_03 = np.load('./pubmed/GCN_accuracy_list_pubmed_laplacian_ratio0.03.npy')
GCN_kmedoid_03 = np.load('./pubmed/GCN_accuracy_list_pubmed_Kmedoid_ncluster200_PropToSdFalse_AggregateLayer2_ratio0.03.npy')
GCN_Grain_ball_03 = np.load('./pubmed/GCN_accuracy_list_pubmed_GRAIN_ball_ratio0.03.npy')
GCN_Grain_NND_03 = np.load('./pubmed/GCN_accuracy_list_pubmed_GRAIN_NND_ratio0.03.npy')
GCN_batch_at_scale_03 = np.load('./pubmed/GCN_accuracy_list_pubmed_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.01_ratio0.01_total_ratio0.03.npy')
GCN_batch_at_scale_embed_03 = np.load('./pubmed/GCN_accuracy_list_pubmed_batch_at_scale_embed_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.01_ratio0.01_total_ratio0.03.npy')


pubmed_random_acc_03 = np.max(GCN_random_03)
pubmed_degree_acc_03 = np.max(GCN_degree_03)
pubmed_laplacian_acc_03 = np.max(GCN_laplacian_03) 
pubmed_kmedoid_acc_03 = np.max(GCN_kmedoid_03)
pubmed_batch_at_scale_acc_03 = np.max(GCN_batch_at_scale_03)
pubmed_batch_at_scale_embed_acc_03 = np.max(GCN_batch_at_scale_embed_03)
pubmed_Grain_ball_acc_03 = np.max(GCN_Grain_ball_01)
pubmed_Grain_NND_acc_03 = np.max(GCN_Grain_NND_03)


GCN_random_04 = np.load('./pubmed/GCN_accuracy_list_pubmed_random_ratio0.04.npy')
GCN_degree_04 = np.load('./pubmed/GCN_accuracy_list_pubmed_degree_ratio0.04.npy')
GCN_laplacian_04 = np.load('./pubmed/GCN_accuracy_list_pubmed_laplacian_ratio0.04.npy')
GCN_kmedoid_04 = np.load('./pubmed/GCN_accuracy_list_pubmed_Kmedoid_ncluster200_PropToSdFalse_AggregateLayer2_ratio0.04.npy')
GCN_Grain_ball_04 = np.load('./pubmed/GCN_accuracy_list_pubmed_GRAIN_ball_ratio0.04.npy')
GCN_Grain_NND_04 = np.load('./pubmed/GCN_accuracy_list_pubmed_GRAIN_NND_ratio0.04.npy')
GCN_batch_at_scale_04 = np.load('./pubmed/GCN_accuracy_list_pubmed_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.01_ratio0.01_total_ratio0.04.npy')
GCN_batch_at_scale_embed_04 = np.load('./pubmed/GCN_accuracy_list_pubmed_batch_at_scale_embed_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.01_ratio0.01_total_ratio0.04.npy')

pubmed_random_acc_04 = np.max(GCN_random_04)
pubmed_degree_acc_04 = np.max(GCN_degree_04)
pubmed_laplacian_acc_04 = np.max(GCN_laplacian_04) 
pubmed_kmedoid_acc_04 = np.max(GCN_kmedoid_04)
pubmed_batch_at_scale_acc_04 = np.max(GCN_batch_at_scale_04)
pubmed_batch_at_scale_embed_acc_04 = np.max(GCN_batch_at_scale_embed_04)
pubmed_Grain_ball_acc_04 = np.max(GCN_Grain_ball_04)
pubmed_Grain_NND_acc_04 = np.max(GCN_Grain_NND_04)


GCN_random_05 = np.load('./pubmed/GCN_accuracy_list_pubmed_random_ratio0.05.npy')
GCN_degree_05 = np.load('./pubmed/GCN_accuracy_list_pubmed_degree_ratio0.05.npy')
GCN_laplacian_05 = np.load('./pubmed/GCN_accuracy_list_pubmed_laplacian_ratio0.05.npy')
GCN_kmedoid_05 = np.load('./pubmed/GCN_accuracy_list_pubmed_Kmedoid_ncluster200_PropToSdFalse_AggregateLayer2_ratio0.05.npy')
GCN_Grain_ball_05 = np.load('./pubmed/GCN_accuracy_list_pubmed_GRAIN_ball_ratio0.05.npy')
GCN_Grain_NND_05 = np.load('./pubmed/GCN_accuracy_list_pubmed_GRAIN_NND_ratio0.05.npy')
GCN_batch_at_scale_05 = np.load('./pubmed/GCN_accuracy_list_pubmed_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.01_ratio0.01_total_ratio0.05.npy')
GCN_batch_at_scale_embed_05 = np.load('./pubmed/GCN_accuracy_list_pubmed_batch_at_scale_embed_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.01_ratio0.01_total_ratio0.05.npy')

pubmed_random_acc_05 = np.max(GCN_random_05)
pubmed_degree_acc_05 = np.max(GCN_degree_05)
pubmed_laplacian_acc_05 = np.max(GCN_laplacian_05) 
pubmed_kmedoid_acc_05 = np.max(GCN_kmedoid_05)
pubmed_batch_at_scale_acc_05 = np.max(GCN_batch_at_scale_05)
pubmed_batch_at_scale_embed_acc_05 = np.max(GCN_batch_at_scale_embed_05)
pubmed_Grain_ball_acc_05 = np.max(GCN_Grain_ball_05)
pubmed_Grain_NND_acc_05 = np.max(GCN_Grain_NND_05)

# %%
row_1 = np.array([pubmed_acc_256, pubmed_random_acc_01, pubmed_degree_acc_01, pubmed_laplacian_acc_01, 
                  pubmed_kmedoid_acc_01, pubmed_Grain_ball_acc_01, pubmed_Grain_NND_acc_01, 
                  pubmed_batch_at_scale_acc_01, pubmed_batch_at_scale_embed_acc_01])

row_2 = np.array([pubmed_acc_256, pubmed_random_acc_03, pubmed_degree_acc_03, pubmed_laplacian_acc_03, 
                  pubmed_kmedoid_acc_03, pubmed_Grain_ball_acc_03, pubmed_Grain_NND_acc_03, 
                  pubmed_batch_at_scale_acc_03, pubmed_batch_at_scale_embed_acc_03])

row_3 = np.array([pubmed_acc_256, pubmed_random_acc_04, pubmed_degree_acc_04, pubmed_laplacian_acc_04, 
                  pubmed_kmedoid_acc_04, pubmed_Grain_ball_acc_04, pubmed_Grain_NND_acc_04, 
                  pubmed_batch_at_scale_acc_04, pubmed_batch_at_scale_embed_acc_04])

row_4 = np.array([pubmed_acc_256, pubmed_random_acc_05, pubmed_degree_acc_05, pubmed_laplacian_acc_05, 
                  pubmed_kmedoid_acc_05, pubmed_Grain_ball_acc_05, pubmed_Grain_NND_acc_05, 
                  pubmed_batch_at_scale_acc_05, pubmed_batch_at_scale_embed_acc_05])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["Pubmed, ratio=0.01", "Pubmed, ratio=0.03", "Pubmed, ratio=0.04"]
names = ["Standard", "Random", "Degree", "Laplacian", "FeatProp (2-layer)", "Grain_ball", "Grain_NND", 
         "GIDUS", "GIDUS+Cluster_embed"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
# Out:
#                     Standard  Random  Degree  Laplacian  FeatProp (2-layer)  \
# Pubmed, ratio=0.01     0.868   0.836   0.801      0.750               0.820
# Pubmed, ratio=0.03     0.868   0.850   0.827      0.836               0.840
# Pubmed, ratio=0.04     0.868   0.848   0.835      0.846               0.834
#
#                     Grain_ball  Grain_NND  GIDUS  GIDUS+Cluster_embed
# Pubmed, ratio=0.01       0.845      0.831  0.820                0.820
# Pubmed, ratio=0.03       0.845      0.856  0.863                0.863
# Pubmed, ratio=0.04       0.852      0.844  0.863                0.862

# %%
row_1 = np.array([pubmed_acc_256, pubmed_random_acc_01, pubmed_laplacian_acc_01, pubmed_kmedoid_acc_01, 
                 pubmed_random_loss_acc_01])
row_2 = np.array([pubmed_acc_256, pubmed_random_acc_05, pubmed_laplacian_acc_05, pubmed_kmedoid_acc_05,
                 pubmed_random_loss_acc_05])

table = np.stack((row_1, row_2))
table = np.around(table, 3)
dataset = ["Pubmed, ratio=0.01", "Pubmed, ratio=0.05"]
names = ["Standard", "Random", "Laplacian", "FeatProp (2-layer)", "Sample w/b loss"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
# Out:
#                     Standard  Random  Laplacian  FeatProp (2-layer)  \
# Pubmed, ratio=0.01     0.903   0.790      0.685               0.830
# Pubmed, ratio=0.05     0.903   0.853      0.848               0.843
#
#                     Sample w/b loss
# Pubmed, ratio=0.01            0.835
# Pubmed, ratio=0.05            0.836

# %%
row_1 = np.array([pubmed_acc, pubmed_random_acc, pubmed_laplacian_acc, pubmed_degree_acc, pubmed_kmedoid_acc, 
                  pubmed_uncertain_acc, pubmed_uncertain_incre_acc, pubmed_uncertain_kick_acc, pubmed_EL2N_incre_acc, 
                  pubmed_EL2N_kick_acc])

table = np.around(row_1, 3).reshape((1, len(row_1)))
dataset = ["Pubmed"]
names = ["Standard", "Random", "Laplacian", "Degree", "KMedoid", "CE", "CE_incre", "CE_kick", "EL2N_incre", "EL2N_kick",]

df = pd.DataFrame(table, columns=names, index = dataset)
# df.insert(0, "Dataset", dataset)
df.round(3)
# Out:
#         Standard  Random  Laplacian  Degree  KMedoid     CE  CE_incre  \
# Pubmed     0.903   0.853      0.854   0.862    0.854  0.893     0.888
#
#         CE_kick  EL2N_incre  EL2N_kick
# Pubmed    0.874       0.876      0.876

# %% [markdown]
# ## Corafull

# %%
GCN_256 = np.load('./corafull/GCN_accuracy_list_corafull.npy')
corafull_acc_256 = np.max(GCN_256)

GCN_random_03 = np.load('./corafull/GCN_accuracy_list_corafull_random_ratio0.03.npy')
GCN_degree_03 = np.load('./corafull/GCN_accuracy_list_corafull_degree_ratio0.03.npy')
GCN_laplacian_03 = np.load('./corafull/GCN_accuracy_list_corafull_laplacian_ratio0.03.npy')
GCN_kmedoid_03 = np.load('./corafull/GCN_accuracy_list_corafull_Kmedoid_ncluster200_PropToSdFalse_AggregateLayer2_ratio0.03.npy')
GCN_Grain_ball_03 = np.load('./corafull/GCN_accuracy_list_corafull_GRAIN_ball_ratio0.03.npy')
GCN_Grain_NND_03 = np.load('./corafull/GCN_accuracy_list_corafull_GRAIN_NND_ratio0.03.npy')
GCN_batch_at_scale_03 = np.load('./corafull/GCN_accuracy_list_corafull_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy30_pretrain_ratio0.01_ratio0.01_total_ratio0.03.npy')


corafull_random_acc_03 = np.max(GCN_random_03)
corafull_degree_acc_03 = np.max(GCN_degree_03)
corafull_laplacian_acc_03 = np.max(GCN_laplacian_03) 
corafull_kmedoid_acc_03 = np.max(GCN_kmedoid_03)
corafull_batch_at_scale_acc_03 = np.max(GCN_batch_at_scale_03)
corafull_Grain_ball_acc_03 = np.max(GCN_Grain_ball_03)
corafull_Grain_NND_acc_03 = np.max(GCN_Grain_NND_03)


GCN_random_05 = np.load('./corafull/GCN_accuracy_list_corafull_random_ratio0.05.npy')
GCN_degree_05 = np.load('./corafull/GCN_accuracy_list_corafull_degree_ratio0.05.npy')
GCN_laplacian_05 = np.load('./corafull/GCN_accuracy_list_corafull_laplacian_ratio0.05.npy')
GCN_kmedoid_05 = np.load('./corafull/GCN_accuracy_list_corafull_Kmedoid_ncluster200_PropToSdFalse_AggregateLayer2_ratio0.05.npy')
GCN_Grain_ball_05 = np.load('./corafull/GCN_accuracy_list_corafull_GRAIN_ball_ratio0.05.npy')
GCN_Grain_NND_05 = np.load('./corafull/GCN_accuracy_list_corafull_GRAIN_NND_ratio0.05.npy')
GCN_batch_at_scale_05 = np.load('./corafull/GCN_accuracy_list_corafull_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy30_pretrain_ratio0.01_ratio0.01_total_ratio0.05.npy')

corafull_random_acc_05 = np.max(GCN_random_05)
corafull_degree_acc_05 = np.max(GCN_degree_05)
corafull_laplacian_acc_05 = np.max(GCN_laplacian_05) 
corafull_kmedoid_acc_05 = np.max(GCN_kmedoid_05)
corafull_batch_at_scale_acc_05 = np.max(GCN_batch_at_scale_05)
corafull_Grain_ball_acc_05 = np.max(GCN_Grain_ball_05)
corafull_Grain_NND_acc_05 = np.max(GCN_Grain_NND_05)


GCN_random_10 = np.load('./corafull/GCN_accuracy_list_corafull_random_ratio0.1.npy')
GCN_degree_10 = np.load('./corafull/GCN_accuracy_list_corafull_degree_ratio0.1.npy')
GCN_laplacian_10 = np.load('./corafull/GCN_accuracy_list_corafull_laplacian_ratio0.1.npy')
GCN_kmedoid_10 = np.load('./corafull/GCN_accuracy_list_corafull_Kmedoid_ncluster200_PropToSdFalse_AggregateLayer2_ratio0.1.npy')
GCN_Grain_ball_10 = np.load('./corafull/GCN_accuracy_list_corafull_GRAIN_ball_ratio0.1.npy')
GCN_Grain_NND_10 = np.load('./corafull/GCN_accuracy_list_corafull_GRAIN_NND_ratio0.1.npy')
GCN_batch_at_scale_10 = np.load('./corafull/GCN_accuracy_list_corafull_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy30_pretrain_ratio0.01_ratio0.01_total_ratio0.1.npy')

corafull_random_acc_10 = np.max(GCN_random_10)
corafull_degree_acc_10 = np.max(GCN_degree_10)
corafull_laplacian_acc_10 = np.max(GCN_laplacian_10) 
corafull_kmedoid_acc_10 = np.max(GCN_kmedoid_10)
corafull_batch_at_scale_acc_10 = np.max(GCN_batch_at_scale_10)
corafull_Grain_ball_acc_10 = np.max(GCN_Grain_ball_10)
corafull_Grain_NND_acc_10 = np.max(GCN_Grain_NND_10)

# %%
row_1 = np.array([corafull_acc_256, corafull_random_acc_03, corafull_degree_acc_03, corafull_laplacian_acc_03, 
                  corafull_kmedoid_acc_03, corafull_Grain_ball_acc_03, corafull_Grain_NND_acc_03, corafull_batch_at_scale_acc_03])
row_2 = np.array([corafull_acc_256, corafull_random_acc_05, corafull_degree_acc_05, corafull_laplacian_acc_05, 
                  corafull_kmedoid_acc_05, corafull_Grain_ball_acc_05, corafull_Grain_NND_acc_05, corafull_batch_at_scale_acc_05])
row_3 = np.array([corafull_acc_256, corafull_random_acc_10, corafull_degree_acc_10, corafull_laplacian_acc_10, 
                  corafull_kmedoid_acc_10, corafull_Grain_ball_acc_10, corafull_Grain_NND_acc_10, corafull_batch_at_scale_acc_10])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["corafull, ratio=0.03", "corafull, ratio=0.05", "corafull, ratio=0.1"]
names = ["Standard", "Random", "Degree", "Laplacian", "FeatProp (2-layer)", "Grain_ball", "Grain_NND", "Uncertain+Cluster"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
# Out:
#                       Standard  Random  Degree  Laplacian  FeatProp (2-layer)  \
# corafull, ratio=0.03     0.656   0.564   0.490      0.435               0.572
# corafull, ratio=0.05     0.656   0.584   0.550      0.481               0.601
# corafull, ratio=0.1      0.656   0.625   0.605      0.571               0.651
#
#                       Grain_ball  Grain_NND  Uncertain+Cluster
# corafull, ratio=0.03       0.593      0.594              0.600
# corafull, ratio=0.05       0.617      0.634              0.620
# corafull, ratio=0.1        0.642      0.664              0.653

# %%
plt.plot(GCN_batch_at_scale_05[1000:-500])
plt.plot(GCN_Grain_NND_03)
plt.plot(GCN_Grain_NND_05)
plt.plot(GCN_Grain_NND_10)

# %% [markdown]
# ## Obgn-arxiv

# %%
Sage_182 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_batchsize182.npy')
Sage_random_002 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_random_ratio0.002.npy')
Sage_laplacian_002 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_laplacian_ratio0.002.npy')
Sage_kmedoid_002 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_AggregateLayer3_ratio0.002.npy')
Sage_kmedoid_l2_002 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_AggregateLayer2_ratio0.002.npy')
Sage_kmedoid_l1_002 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_AggregateLayer1_ratio0.002.npy')
Sage_label_cluster_002 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_label_cluster_AggregateLayer3_ratio0.002.npy')

arxiv_acc_182 = np.max(Sage_182)
arxiv_random_acc_002 = np.max(Sage_random_002)
arxiv_laplacian_acc_002 = np.max(Sage_laplacian_002)
arxiv_kmedoid_acc_002 = np.max(Sage_kmedoid_002) 
arxiv_kmedoid_acc_l2_002 = np.max(Sage_kmedoid_l2_002)
arxiv_kmedoid_acc_l1_002 = np.max(Sage_kmedoid_l1_002)
arxiv_label_cluster_acc_002 = np.max(Sage_label_cluster_002)
arxiv_batch_at_scale_acc_002 = arxiv_kmedoid_acc_002

Sage_random_005 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_random_ratio0.005.npy')
Sage_laplacian_005 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_laplacian_ratio0.005.npy')
Sage_kmedoid_005 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_ncluster454_AggregateLayer3_ratio0.005.npy')
Sage_kmedoid_l2_005 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_AggregateLayer2_ratio0.005.npy')
Sage_kmedoid_l1_005 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_AggregateLayer1_ratio0.005.npy')
Sage_label_cluster_005 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_label_cluster_AggregateLayer3_ratio0.005.npy')
Sage_batch_at_scale_005 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_batch_at_scale_cold_startTrue_redundancy40_pretrain_ratio0.0025_ratio0.0005_total_ratio0.005.npy')

arxiv_random_acc_005 = np.max(Sage_random_005)
arxiv_laplacian_acc_005 = np.max(Sage_laplacian_005)
arxiv_kmedoid_acc_005 = np.max(Sage_kmedoid_005)
arxiv_kmedoid_acc_l2_005 = np.max(Sage_kmedoid_l2_005)
arxiv_kmedoid_acc_l1_005 = np.max(Sage_kmedoid_l1_005)
arxiv_label_cluster_acc_005 = np.max(Sage_label_cluster_005)
arxiv_batch_at_scale_acc_005 = np.max(Sage_batch_at_scale_005)

Sage_random_01 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_random_ratio0.01.npy')
Sage_laplacian_01 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_laplacian_ratio0.01.npy')
Sage_kmedoid_01 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_ncluster200_PropToSdTrue_AggregateLayer3_ratio0.01.npy')
Sage_kmedoid_l2_01 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_AggregateLayer2_ratio0.01.npy')
Sage_kmedoid_l1_01 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_AggregateLayer1_ratio0.01.npy')
Sage_label_cluster_01 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_label_cluster_AggregateLayer3_ratio0.01.npy')
Sage_batch_at_scale_01 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_batch_at_scale_cold_startTrue_redundancy40_pretrain_ratio0.0025_ratio0.0005_total_ratio0.01.npy')

arxiv_random_acc_01 = np.max(Sage_random_01)
arxiv_laplacian_acc_01 = np.max(Sage_laplacian_01)
arxiv_kmedoid_acc_01 = np.max(Sage_kmedoid_01) 
arxiv_kmedoid_acc_l2_01 = np.max(Sage_kmedoid_l2_01)
arxiv_kmedoid_acc_l1_01 = np.max(Sage_kmedoid_l1_01)
arxiv_label_cluster_acc_01 = np.max(Sage_label_cluster_01)
arxiv_batch_at_scale_acc_01 = np.max(Sage_batch_at_scale_01)

# %%
Sage_256 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv.npy')
Sage_random_05 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_random_ratio0.05.npy')
Sage_laplacian_05 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_laplacian_ratio0.05.npy')
Sage_degree_05 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_degree_ratio0.05.npy')
Sage_kmedoid_05 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_ncluster100_AggregateLayer3_ratio0.05.npy')
Sage_label_cluster_05 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_label_cluster_AggregateLayer3_ratio0.05.npy')
Sage_uncertain = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_active_random_uncertain_epochs300_pretrain10_ratio0.05_sample_freq20.npy')
Sage_uncertain_incre = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_active_random_uncertain_increment_pretrain10_epochs300_pretrain_ratio0.05_ratio0.01_sample_freq20.npy')
Sage_uncertain_kick = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_active_random_uncertain_kick_out_pretrain10_epochs300_pretrain_ratio0.05_ratio0.01_sample_freq20.npy')
Sage_EL2N_incre = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_active_random_EL2N_increment_pretrain10_epochs300_pretrain_ratio0.05_ratio0.01_sample_freq20.npy')
Sage_EL2N_kick = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_active_random_EL2N_kick_out_pretrain10_epochs300_pretrain_ratio0.05_ratio0.01_sample_freq20.npy')



arxiv_acc_256 = np.max(Sage_256)
arxiv_random_acc_05 = np.max(Sage_random_05)
arxiv_laplacian_acc_05 = np.max(Sage_laplacian_05)
arxiv_degree_acc_05 = np.max(Sage_degree_05) 
arxiv_kmedoid_acc_05 = np.max(Sage_kmedoid_05) 
arxiv_label_cluster_acc_05 = np.max(Sage_label_cluster_05)
arxiv_uncertain_acc = np.max(Sage_uncertain)
arxiv_uncertain_incre_acc = np.max(Sage_uncertain_incre)
arxiv_uncertain_kick_acc = np.max(Sage_uncertain_kick)
arxiv_EL2N_incre_acc = np.max(Sage_EL2N_incre)
arxiv_EL2N_kick_acc = np.max(Sage_EL2N_kick)

# %%
row_1 = np.array([arxiv_acc_256, arxiv_random_acc_002, arxiv_laplacian_acc_002, arxiv_kmedoid_acc_002, 
                  arxiv_label_cluster_acc_002, arxiv_batch_at_scale_acc_002])
row_2 = np.array([arxiv_acc_256, arxiv_random_acc_005, arxiv_laplacian_acc_005, arxiv_kmedoid_acc_005, 
                  arxiv_label_cluster_acc_005, arxiv_batch_at_scale_acc_005])
row_3 = np.array([arxiv_acc_256, arxiv_random_acc_01, arxiv_laplacian_acc_01, arxiv_kmedoid_acc_01, 
                  arxiv_label_cluster_acc_01, arxiv_batch_at_scale_acc_01])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["arxiv, ratio=0.002", "arxiv, ratio=0.005", "arxiv, ratio=0.01"]
names = ["Standard", "Random", "Laplacian", "FeatProp (3-layer)", "LabelProp (3-layer)", "Batch at Scale"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
# Out:
#                     Standard  Random  Laplacian  FeatProp (3-layer)  \
# arxiv, ratio=0.002     0.702   0.526      0.553               0.552
# arxiv, ratio=0.005     0.702   0.572      0.605               0.595
# arxiv, ratio=0.01      0.702   0.630      0.611               0.608
#
#                     LabelProp (3-layer)  Batch at Scale
# arxiv, ratio=0.002                0.535           0.552
# arxiv, ratio=0.005                0.564           0.585
# arxiv, ratio=0.01                 0.608           0.598

# %%
row_1 = np.array([arxiv_acc_256, arxiv_random_acc_002, arxiv_laplacian_acc_002, arxiv_kmedoid_acc_002, arxiv_label_cluster_acc_002])
row_2 = np.array([arxiv_acc_256, arxiv_random_acc_005, arxiv_laplacian_acc_005, arxiv_kmedoid_acc_005, arxiv_label_cluster_acc_005])
row_3 = np.array([arxiv_acc_256, arxiv_random_acc_01, arxiv_laplacian_acc_01, arxiv_kmedoid_acc_01, arxiv_label_cluster_acc_01])
row_4 = np.array([arxiv_acc_256, arxiv_random_acc_05, arxiv_laplacian_acc_05, arxiv_kmedoid_acc_05, arxiv_label_cluster_acc_05])


table = np.stack((row_1, row_2, row_3, row_4))
table = np.around(table, 3)
dataset = ["arxiv, ratio=0.002", "arxiv, ratio=0.005", "arxiv, ratio=0.01", "arxiv, ratio=0.05"]
names = ["Standard", "Random", "Laplacian", "FeatProp (3-layer)", "LabelProp (3-layer)"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
# Out:
#                     Standard  Random  Laplacian  FeatProp (3-layer)  \
# arxiv, ratio=0.002     0.702   0.526      0.553               0.552
# arxiv, ratio=0.005     0.702   0.572      0.605               0.595
# arxiv, ratio=0.01      0.702   0.618      0.611               0.608
# arxiv, ratio=0.05      0.702   0.656      0.659               0.653
#
#                     LabelProp (3-layer)
# arxiv, ratio=0.002                0.535
# arxiv, ratio=0.005                0.564
# arxiv, ratio=0.01                 0.608
# arxiv, ratio=0.05                 0.653

# %%
row_1 = np.array([arxiv_kmedoid_acc_002, arxiv_kmedoid_acc_l2_002, arxiv_kmedoid_acc_l1_002])
row_2 = np.array([arxiv_kmedoid_acc_005, arxiv_kmedoid_acc_l2_005, arxiv_kmedoid_acc_l1_005])
row_3 = np.array([arxiv_kmedoid_acc_01, arxiv_kmedoid_acc_l2_01, arxiv_kmedoid_acc_l1_01])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["arxiv, ratio=0.002", "arxiv, ratio=0.005", "arxiv, ratio=0.01"]
names = ["FeatProp (3-layer)", "FeatProp (2-layer)", "FeatProp (1-layer)"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
# Out:
#                     FeatProp (3-layer)  FeatProp (2-layer)  FeatProp (1-layer)
# arxiv, ratio=0.002               0.264               0.228               0.252
# arxiv, ratio=0.005               0.329               0.319               0.335
# arxiv, ratio=0.01                0.345               0.364               0.388

# %%
row_1 = np.array([pubmed_acc, pubmed_random_acc, pubmed_laplacian_acc, pubmed_degree_acc, pubmed_uncertain_acc, 
                  pubmed_uncertain_incre_acc, pubmed_uncertain_kick_acc, pubmed_EL2N_incre_acc, pubmed_EL2N_kick_acc])
row_2 = np.array([arxiv_acc, arxiv_random_acc, arxiv_laplacian_acc, arxiv_degree_acc, arxiv_uncertain_acc, 
                  arxiv_uncertain_incre_acc, arxiv_uncertain_kick_acc, arxiv_EL2N_incre_acc, arxiv_EL2N_kick_acc])

table = np.stack((row_1, row_2))
table = np.around(table, 3)
dataset = ["Pubmed", "obgn-arxiv"]
names = ["Standard", "Random", "Laplacian", "Degree", "CE", "CE_incre", "CE_kick", "EL2N_incre", "EL2N_kick",]

df = pd.DataFrame(table, columns=names, index = dataset)
# df.insert(0, "Dataset", dataset)
df.round(3)
# Out:
#             Standard  Random  Laplacian  Degree     CE  CE_incre  CE_kick  \
# Pubmed         0.903   0.881      0.875   0.862  0.893     0.888    0.874
# obgn-arxiv     0.702   0.656      0.659   0.618  0.658     0.664    0.653
#
#             EL2N_incre  EL2N_kick
# Pubmed           0.876      0.876
# obgn-arxiv       0.651      0.647
