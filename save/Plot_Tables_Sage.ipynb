# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Citeseer Dataset

# %%
Sage_256 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batchsize256.npy')
Sage_random_03 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_random_ratio0.03.npy')
Sage_laplacian_03 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_laplacian_ratio0.03.npy')
Sage_degree_03 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_degree_ratio0.03.npy')
Sage_kmedoid_03 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_Kmedoid_ncluster54_PropToSdFalse_AggregateLayer2_ratio0.03.npy')
Sage_Grain_ball_03 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_ball_ratio0.03.npy')
Sage_Grain_NND_03 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_NND_ratio0.03.npy')

citeseer_acc_256 = np.max(Sage_256)
citeseer_random_acc_03 = np.max(Sage_random_03)
citeseer_degree_acc_03 = np.max(Sage_degree_03)
citeseer_laplacian_acc_03 = np.max(Sage_laplacian_03) 
citeseer_kmedoid_acc_03 = np.max(Sage_kmedoid_03)
citeseer_batch_at_scale_acc_03 = citeseer_kmedoid_acc_03
citeseer_batch_at_scale_random_acc_03 = citeseer_kmedoid_acc_03
citeseer_batch_at_scale_round_robin_acc_03 = citeseer_kmedoid_acc_03
citeseer_batch_at_scale_cluster_input_acc_03 = citeseer_kmedoid_acc_03
citeseer_batch_at_scale_cluster_embed_acc_03 = citeseer_kmedoid_acc_03
citeseer_Grain_ball_acc_03 = np.max(Sage_Grain_ball_03)
citeseer_Grain_NND_acc_03 = np.max(Sage_Grain_NND_03)


Sage_random_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_random_ratio0.05.npy')
Sage_degree_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_degree_ratio0.05.npy')
Sage_laplacian_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_laplacian_ratio0.05.npy')
Sage_kmedoid_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_Kmedoid_ncluster91_PropToSdFalse_AggregateLayer2_ratio0.05.npy')
Sage_batch_at_scale_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_batch_at_scale_random_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_random_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_batch_at_scale_round_robin_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_batch_at_scale_cluster_input_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_input_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_batch_at_scale_cluster_embed_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_embed_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_Grain_ball_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_ball_ratio0.05.npy')
Sage_Grain_NND_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_NND_ratio0.05.npy')

citeseer_random_acc_05 = np.max(Sage_random_05)
citeseer_degree_acc_05 = np.max(Sage_degree_05)
citeseer_laplacian_acc_05 = np.max(Sage_laplacian_05) 
citeseer_kmedoid_acc_05 = np.max(Sage_kmedoid_05)
citeseer_batch_at_scale_acc_05 = np.max(Sage_batch_at_scale_05)
citeseer_batch_at_scale_random_acc_05 = np.max(Sage_batch_at_scale_random_05)
citeseer_batch_at_scale_round_robin_acc_05 = np.max(Sage_batch_at_scale_round_robin_05)
citeseer_batch_at_scale_cluster_input_acc_05 = np.max(Sage_batch_at_scale_cluster_input_05)
citeseer_batch_at_scale_cluster_embed_acc_05 = np.max(Sage_batch_at_scale_cluster_embed_05)
citeseer_Grain_ball_acc_05 = np.max(Sage_Grain_ball_05)
citeseer_Grain_NND_acc_05 = np.max(Sage_Grain_NND_05)


Sage_random_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_random_ratio0.1.npy')
Sage_degree_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_degree_ratio0.1.npy')
Sage_laplacian_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_laplacian_ratio0.1.npy')
Sage_kmedoid_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_Kmedoid_ncluster182_PropToSdFalse_AggregateLayer2_ratio0.1.npy')
Sage_batch_at_scale_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.1.npy') 
Sage_batch_at_scale_random_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_random_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.1.npy')
Sage_batch_at_scale_round_robin_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.1.npy')
Sage_batch_at_scale_cluster_input_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_input_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.1.npy')
Sage_batch_at_scale_cluster_embed_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_embed_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.1.npy')
Sage_Grain_ball_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_ball_ratio0.1.npy')
Sage_Grain_NND_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_NND_ratio0.1.npy')

citeseer_random_acc_10 = np.max(Sage_random_10)
citeseer_degree_acc_10 = np.max(Sage_degree_10)
citeseer_laplacian_acc_10 = np.max(Sage_laplacian_10) 
citeseer_kmedoid_acc_10 = np.max(Sage_kmedoid_10)
citeseer_batch_at_scale_acc_10 = np.max(Sage_batch_at_scale_10)
citeseer_batch_at_scale_random_acc_10 = np.max(Sage_batch_at_scale_random_10)
citeseer_batch_at_scale_round_robin_acc_10 = np.max(Sage_batch_at_scale_round_robin_10)
citeseer_batch_at_scale_cluster_input_acc_10 = np.max(Sage_batch_at_scale_cluster_input_10)
citeseer_batch_at_scale_cluster_embed_acc_10 = np.max(Sage_batch_at_scale_cluster_embed_10)
citeseer_Grain_ball_acc_10 = np.max(Sage_Grain_ball_10)
citeseer_Grain_NND_acc_10 = np.max(Sage_Grain_NND_10)

# %%
row_1 = np.array([citeseer_acc_256, citeseer_random_acc_03, citeseer_degree_acc_03, citeseer_laplacian_acc_03, 
                  citeseer_kmedoid_acc_03, citeseer_Grain_ball_acc_03, citeseer_Grain_NND_acc_03,
                  citeseer_batch_at_scale_acc_03])
row_2 = np.array([citeseer_acc_256, citeseer_random_acc_05, citeseer_degree_acc_05, citeseer_laplacian_acc_05, 
                  citeseer_kmedoid_acc_05, citeseer_Grain_ball_acc_05, citeseer_Grain_NND_acc_05,
                  citeseer_batch_at_scale_acc_05])
row_3 = np.array([citeseer_acc_256, citeseer_random_acc_10, citeseer_degree_acc_10, citeseer_laplacian_acc_10, 
                  citeseer_kmedoid_acc_10, citeseer_Grain_ball_acc_10, citeseer_Grain_NND_acc_10,
                  citeseer_batch_at_scale_acc_10])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["citeseer, ratio=0.03", "citeseer, ratio=0.05", "citeseer, ratio=0.1"]
names = ["Standard", "Random", "Degree", "Laplacian", "FeatProp (2-layer)", "Grain_ball", "Grain_NND", "GIDUS"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
display(df)


row_1 = np.array([citeseer_batch_at_scale_acc_03, citeseer_batch_at_scale_random_acc_03, citeseer_batch_at_scale_round_robin_acc_03,
                 citeseer_batch_at_scale_cluster_input_acc_03, citeseer_batch_at_scale_cluster_embed_acc_03])
row_2 = np.array([citeseer_batch_at_scale_acc_05, citeseer_batch_at_scale_random_acc_05, citeseer_batch_at_scale_round_robin_acc_05, 
                  citeseer_batch_at_scale_cluster_input_acc_05, citeseer_batch_at_scale_cluster_embed_acc_05])
row_3 = np.array([citeseer_batch_at_scale_acc_10, citeseer_batch_at_scale_random_acc_10, citeseer_batch_at_scale_round_robin_acc_10, 
                  citeseer_batch_at_scale_cluster_input_acc_10, citeseer_batch_at_scale_cluster_embed_acc_10])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["citeseer, ratio=0.03", "citeseer, ratio=0.05", "citeseer, ratio=0.1"]
names = ["GIDUS (kmeans++)", "GIDUS (random)", "GIDUS (round robin)", "GIDUS (cluster input)", "GIDUS (cluster embed)"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
display(df)
# Out:
#                       Standard  Random  Degree  Laplacian  FeatProp (2-layer)  \
# citeseer, ratio=0.03     0.803   0.589   0.395      0.324               0.592
# citeseer, ratio=0.05     0.803   0.626   0.471      0.639               0.620
# citeseer, ratio=0.1      0.803   0.685   0.638      0.698               0.670
#
#                       Grain_ball  Grain_NND  GIDUS
# citeseer, ratio=0.03       0.619      0.619  0.592
# citeseer, ratio=0.05       0.680      0.688  0.709
# citeseer, ratio=0.1        0.715      0.720  0.736
#                       GIDUS (kmeans++)  GIDUS (random)  GIDUS (round robin)  \
# citeseer, ratio=0.03             0.592           0.592                0.592
# citeseer, ratio=0.05             0.709           0.699                0.689
# citeseer, ratio=0.1              0.736           0.737                0.732
#
#                       GIDUS (cluster input)  GIDUS (cluster embed)
# citeseer, ratio=0.03                  0.592                  0.592
# ...

# %% [markdown]
# ## Cora Dataset

# %%
Sage_256 = np.load('./cora/GraphSage_accuracy_list_cora_batchsize256.npy')
Sage_random_03 = np.load('./cora/GraphSage_accuracy_list_cora_random_ratio0.03.npy')
Sage_degree_03 = np.load('./cora/GraphSage_accuracy_list_cora_degree_ratio0.03.npy')
Sage_laplacian_03 = np.load('./cora/GraphSage_accuracy_list_cora_laplacian_ratio0.03.npy')
Sage_kmedoid_03 = np.load('./cora/GraphSage_accuracy_list_cora_Kmedoid_ncluster36_PropToSdFalse_AggregateLayer2_ratio0.03.npy')
Sage_batch_at_scale_03 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.02_ratio0.01_total_ratio0.03.npy')
Sage_Grain_ball_03 = np.load('./cora/GraphSage_accuracy_list_cora_GRAIN_ball_ratio0.03.npy')
Sage_Grain_NND_03 = np.load('./cora/GraphSage_accuracy_list_cora_GRAIN_NND_ratio0.03.npy')


cora_random_acc_03 = np.max(Sage_random_03)
cora_degree_acc_03 = np.max(Sage_degree_03)
cora_laplacian_acc_03 = np.max(Sage_laplacian_03) 
cora_kmedoid_acc_03 = np.max(Sage_kmedoid_03)
cora_batch_at_scale_acc_03 = np.max(Sage_batch_at_scale_03)
cora_batch_at_scale_random_acc_03 = cora_kmedoid_acc_03
cora_batch_at_scale_round_robin_acc_03 = cora_kmedoid_acc_03
cora_batch_at_scale_cluster_input_acc_03 = cora_kmedoid_acc_03
cora_batch_at_scale_cluster_embed_acc_03 = cora_kmedoid_acc_03
cora_Grain_ball_03 = np.max(Sage_Grain_ball_03)
cora_Grain_NND_03 = np.max(Sage_Grain_NND_03)



Sage_random_05 = np.load('./cora/GraphSage_accuracy_list_cora_random_ratio0.05.npy')
Sage_degree_05 = np.load('./cora/GraphSage_accuracy_list_cora_degree_ratio0.05.npy')
Sage_laplacian_05 = np.load('./cora/GraphSage_accuracy_list_cora_laplacian_ratio0.05.npy')
Sage_kmedoid_05 = np.load('./cora/GraphSage_accuracy_list_cora_Kmedoid_ncluster60_PropToSdFalse_AggregateLayer2_ratio0.05.npy')
Sage_batch_at_scale_05 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_batch_at_scale_random_05 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_random_choice_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_batch_at_scale_round_robin_05 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_batch_at_scale_cluster_input_05 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_cluster_input_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_batch_at_scale_cluster_embed_05 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_cluster_embed_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_Grain_ball_05 = np.load('./cora/GraphSage_accuracy_list_cora_GRAIN_ball_ratio0.05.npy')
Sage_Grain_NND_05 = np.load('./cora/GraphSage_accuracy_list_cora_GRAIN_NND_ratio0.05.npy')


cora_acc_256 = np.max(Sage_256)
cora_random_acc_05 = np.max(Sage_random_05)
cora_degree_acc_05 = np.max(Sage_degree_05)
cora_laplacian_acc_05 = np.max(Sage_laplacian_05) 
cora_kmedoid_acc_05 = np.max(Sage_kmedoid_05)
cora_batch_at_scale_acc_05 = np.max(Sage_batch_at_scale_05)
cora_batch_at_scale_random_acc_05 = np.max(Sage_batch_at_scale_random_05)
cora_batch_at_scale_round_robin_acc_05 = np.max(Sage_batch_at_scale_round_robin_05)
cora_batch_at_scale_cluster_input_acc_05 = np.max(Sage_batch_at_scale_cluster_input_05)
cora_batch_at_scale_cluster_embed_acc_05 = np.max(Sage_batch_at_scale_cluster_embed_05)
cora_Grain_ball_05 = np.max(Sage_Grain_ball_05)
cora_Grain_NND_05 = np.max(Sage_Grain_NND_05)


Sage_random_06 = np.load('./cora/GraphSage_accuracy_list_cora_random_ratio0.06.npy')
Sage_degree_06 = np.load('./cora/GraphSage_accuracy_list_cora_degree_ratio0.06.npy')
Sage_laplacian_06 = np.load('./cora/GraphSage_accuracy_list_cora_laplacian_ratio0.06.npy')
Sage_kmedoid_06 = np.load('./cora/GraphSage_accuracy_list_cora_Kmedoid_ncluster72_PropToSdFalse_AggregateLayer2_ratio0.06.npy')
Sage_batch_at_scale_06 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.02_ratio0.01_total_ratio0.06.npy')
Sage_batch_at_scale_random_06 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_random_choice_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.06.npy')
Sage_batch_at_scale_round_robin_06 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.06.npy')
Sage_batch_at_scale_cluster_input_06 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_cluster_input_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.06.npy')
Sage_batch_at_scale_cluster_embed_06 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_cluster_embed_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.06.npy')
Sage_Grain_ball_06 = np.load('./cora/GraphSage_accuracy_list_cora_GRAIN_ball_ratio0.06.npy')
Sage_Grain_NND_06 = np.load('./cora/GraphSage_accuracy_list_cora_GRAIN_NND_ratio0.06.npy')


cora_acc_256 = np.max(Sage_256)
cora_random_acc_06 = np.max(Sage_random_06)
cora_degree_acc_06 = np.max(Sage_degree_06)
cora_laplacian_acc_06 = np.max(Sage_laplacian_06) 
cora_kmedoid_acc_06 = np.max(Sage_kmedoid_06)
cora_batch_at_scale_acc_06 = np.max(Sage_batch_at_scale_06)
cora_batch_at_scale_random_acc_06 = np.max(Sage_batch_at_scale_random_06)
cora_batch_at_scale_round_robin_acc_06 = np.max(Sage_batch_at_scale_round_robin_06)
cora_batch_at_scale_cluster_input_acc_06 = np.max(Sage_batch_at_scale_cluster_input_06)
cora_batch_at_scale_cluster_embed_acc_06 = np.max(Sage_batch_at_scale_cluster_embed_06)
cora_Grain_ball_06 = np.max(Sage_Grain_ball_06)
cora_Grain_NND_06 = np.max(Sage_Grain_NND_06)


Sage_random_07 = np.load('./cora/GraphSage_accuracy_list_cora_random_ratio0.07.npy')
Sage_degree_07 = np.load('./cora/GraphSage_accuracy_list_cora_degree_ratio0.07.npy')
Sage_laplacian_07 = np.load('./cora/GraphSage_accuracy_list_cora_laplacian_ratio0.07.npy')
Sage_kmedoid_07 = np.load('./cora/GraphSage_accuracy_list_cora_Kmedoid_ncluster84_PropToSdFalse_AggregateLayer2_ratio0.07.npy')
Sage_batch_at_scale_07 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.02_ratio0.01_total_ratio0.07.npy')
Sage_batch_at_scale_random_07 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_random_choice_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.07.npy')
Sage_batch_at_scale_round_robin_07 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.07.npy')
Sage_batch_at_scale_cluster_input_07 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_cluster_input_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.07.npy')
Sage_batch_at_scale_cluster_embed_07 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_cluster_embed_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.07.npy')
Sage_Grain_ball_07 = np.load('./cora/GraphSage_accuracy_list_cora_GRAIN_ball_ratio0.07.npy')
Sage_Grain_NND_07 = np.load('./cora/GraphSage_accuracy_list_cora_GRAIN_NND_ratio0.07.npy')


cora_acc_256 = np.max(Sage_256)
cora_random_acc_07 = np.max(Sage_random_07)
cora_degree_acc_07 = np.max(Sage_degree_07)
cora_laplacian_acc_07 = np.max(Sage_laplacian_07) 
cora_kmedoid_acc_07 = np.max(Sage_kmedoid_07)
cora_batch_at_scale_acc_07 = np.max(Sage_batch_at_scale_07)
cora_batch_at_scale_random_acc_07 = np.max(Sage_batch_at_scale_random_07)
cora_batch_at_scale_round_robin_acc_07 = np.max(Sage_batch_at_scale_round_robin_07)
cora_batch_at_scale_cluster_input_acc_07 = np.max(Sage_batch_at_scale_cluster_input_07)
cora_batch_at_scale_cluster_embed_acc_07 = np.max(Sage_batch_at_scale_cluster_embed_07)
cora_Grain_ball_07 = np.max(Sage_Grain_ball_07)
cora_Grain_NND_07 = np.max(Sage_Grain_NND_07)


Sage_random_08 = np.load('./cora/GraphSage_accuracy_list_cora_random_ratio0.08.npy')
Sage_degree_08 = np.load('./cora/GraphSage_accuracy_list_cora_degree_ratio0.08.npy')
Sage_laplacian_08 = np.load('./cora/GraphSage_accuracy_list_cora_laplacian_ratio0.08.npy')
Sage_kmedoid_08 = np.load('./cora/GraphSage_accuracy_list_cora_Kmedoid_ncluster96_PropToSdFalse_AggregateLayer2_ratio0.08.npy')
Sage_batch_at_scale_08 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.02_ratio0.01_total_ratio0.08.npy')
Sage_batch_at_scale_random_08 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_random_choice_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.08.npy')
Sage_batch_at_scale_round_robin_08 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.08.npy')
Sage_batch_at_scale_cluster_input_08 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_cluster_input_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.08.npy')
Sage_batch_at_scale_cluster_embed_08 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_cluster_embed_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.08.npy')
Sage_Grain_ball_08 = np.load('./cora/GraphSage_accuracy_list_cora_GRAIN_ball_ratio0.08.npy')
Sage_Grain_NND_08 = np.load('./cora/GraphSage_accuracy_list_cora_GRAIN_NND_ratio0.08.npy')


cora_acc_256 = np.max(Sage_256)
cora_random_acc_08 = np.max(Sage_random_08)
cora_degree_acc_08 = np.max(Sage_degree_08)
cora_laplacian_acc_08 = np.max(Sage_laplacian_08) 
cora_kmedoid_acc_08 = np.max(Sage_kmedoid_08)
cora_batch_at_scale_acc_08 = np.max(Sage_batch_at_scale_08)
cora_batch_at_scale_random_acc_08 = np.max(Sage_batch_at_scale_random_08)
cora_batch_at_scale_round_robin_acc_08 = np.max(Sage_batch_at_scale_round_robin_08)
cora_batch_at_scale_cluster_input_acc_08 = np.max(Sage_batch_at_scale_cluster_input_08)
cora_batch_at_scale_cluster_embed_acc_08 = np.max(Sage_batch_at_scale_cluster_embed_08)
cora_Grain_ball_08 = np.max(Sage_Grain_ball_08)
cora_Grain_NND_08 = np.max(Sage_Grain_NND_08)



Sage_random_09 = np.load('./cora/GraphSage_accuracy_list_cora_random_ratio0.09.npy')
Sage_degree_09 = np.load('./cora/GraphSage_accuracy_list_cora_degree_ratio0.09.npy')
Sage_laplacian_09 = np.load('./cora/GraphSage_accuracy_list_cora_laplacian_ratio0.09.npy')
Sage_kmedoid_09 = np.load('./cora/GraphSage_accuracy_list_cora_Kmedoid_ncluster108_PropToSdFalse_AggregateLayer2_ratio0.09.npy')
Sage_batch_at_scale_09 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.09.npy')
Sage_batch_at_scale_random_09 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_random_choice_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.09.npy')
Sage_batch_at_scale_round_robin_09 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.09.npy')
Sage_batch_at_scale_cluster_input_09 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_cluster_input_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.09.npy')
Sage_batch_at_scale_cluster_embed_09 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_cluster_embed_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.09.npy')
Sage_Grain_ball_09 = np.load('./cora/GraphSage_accuracy_list_cora_GRAIN_ball_ratio0.09.npy')
Sage_Grain_NND_09 = np.load('./cora/GraphSage_accuracy_list_cora_GRAIN_NND_ratio0.09.npy')


cora_acc_256 = np.max(Sage_256)
cora_random_acc_09 = np.max(Sage_random_09)
cora_degree_acc_09 = np.max(Sage_degree_09)
cora_laplacian_acc_09 = np.max(Sage_laplacian_09) 
cora_kmedoid_acc_09 = np.max(Sage_kmedoid_09)
cora_batch_at_scale_acc_09 = np.max(Sage_batch_at_scale_09)
cora_batch_at_scale_random_acc_09 = np.max(Sage_batch_at_scale_random_09)
cora_batch_at_scale_round_robin_acc_09 = np.max(Sage_batch_at_scale_round_robin_09)
cora_batch_at_scale_cluster_input_acc_09 = np.max(Sage_batch_at_scale_cluster_input_09)
cora_batch_at_scale_cluster_embed_acc_09 = np.max(Sage_batch_at_scale_cluster_embed_09)
cora_Grain_ball_09 = np.max(Sage_Grain_ball_09)
cora_Grain_NND_09 = np.max(Sage_Grain_NND_09)



Sage_random_10 = np.load('./cora/GraphSage_accuracy_list_cora_random_ratio0.1.npy')
Sage_degree_10 = np.load('./cora/GraphSage_accuracy_list_cora_degree_ratio0.1.npy')
Sage_laplacian_10 = np.load('./cora/GraphSage_accuracy_list_cora_laplacian_ratio0.1.npy')
Sage_kmedoid_10 = np.load('./cora/GraphSage_accuracy_list_cora_Kmedoid_ncluster120_PropToSdFalse_AggregateLayer2_ratio0.1.npy')
Sage_batch_at_scale_10 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.1.npy') 
Sage_batch_at_scale_r10_10 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_cold_startFalse_redundancy10_pretrain_ratio0.04_ratio0.01_total_ratio0.1.npy') 
Sage_batch_at_scale_r5_10 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_cold_startFalse_redundancy5_pretrain_ratio0.04_ratio0.01_total_ratio0.1.npy') 
Sage_batch_at_scale_r1_10 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_cold_startFalse_redundancy1_pretrain_ratio0.04_ratio0.01_total_ratio0.1.npy') 
Sage_batch_at_scale_random_10 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_random_choice_cold_startFalse_redundancy10_pretrain_ratio0.04_ratio0.01_total_ratio0.1.npy')
Sage_batch_at_scale_round_robin_10 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy10_pretrain_ratio0.04_ratio0.01_total_ratio0.1.npy')
Sage_batch_at_scale_cluster_input_10 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_cluster_input_cold_startFalse_redundancy20_pretrain_ratio0.04_ratio0.01_total_ratio0.1.npy')
Sage_batch_at_scale_cluster_embed_10 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_cluster_embed_cold_startFalse_redundancy20_pretrain_ratio0.04_ratio0.01_total_ratio0.1.npy')
Sage_Grain_ball_10 = np.load('./cora/GraphSage_accuracy_list_cora_GRAIN_ball_ratio0.1.npy')
Sage_Grain_NND_10 = np.load('./cora/GraphSage_accuracy_list_cora_GRAIN_NND_ratio0.1.npy')



cora_random_acc_10 = np.max(Sage_random_10)
cora_degree_acc_10 = np.max(Sage_degree_10)
cora_laplacian_acc_10 = np.max(Sage_laplacian_10) 
cora_kmedoid_acc_10 = np.max(Sage_kmedoid_10)
cora_batch_at_scale_acc_10 = np.max(Sage_batch_at_scale_10)
cora_batch_at_scale_r10_acc_10 = np.max(Sage_batch_at_scale_r10_10)
cora_batch_at_scale_r5_acc_10 = np.max(Sage_batch_at_scale_r5_10)
cora_batch_at_scale_r1_acc_10 = np.max(Sage_batch_at_scale_r1_10)
cora_batch_at_scale_random_acc_10 = np.max(Sage_batch_at_scale_random_10)
cora_batch_at_scale_round_robin_acc_10 = np.max(Sage_batch_at_scale_round_robin_10)
cora_batch_at_scale_cluster_input_acc_10 = np.max(Sage_batch_at_scale_cluster_input_10)
cora_batch_at_scale_cluster_embed_acc_10 = np.max(Sage_batch_at_scale_cluster_embed_10)
cora_Grain_ball_10 = np.max(Sage_Grain_ball_10)
cora_Grain_NND_10 = np.max(Sage_Grain_NND_10)


Sage_random_15 = np.load('./cora/GraphSage_accuracy_list_cora_random_ratio0.15.npy')
Sage_degree_15 = np.load('./cora/GraphSage_accuracy_list_cora_degree_ratio0.15.npy')
Sage_laplacian_15 = np.load('./cora/GraphSage_accuracy_list_cora_laplacian_ratio0.15.npy')
Sage_kmedoid_15 = np.load('./cora/GraphSage_accuracy_list_cora_Kmedoid_ncluster181_PropToSdFalse_AggregateLayer2_ratio0.15.npy')
Sage_batch_at_scale_15 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.15.npy')
Sage_batch_at_scale_random_15 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_random_choice_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.15.npy')
Sage_batch_at_scale_round_robin_15 = np.load('./cora/GraphSage_accuracy_list_cora_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.15.npy')
Sage_Grain_ball_15 = np.load('./cora/GraphSage_accuracy_list_cora_GRAIN_ball_ratio0.15.npy')
Sage_Grain_NND_15 = np.load('./cora/GraphSage_accuracy_list_cora_GRAIN_NND_ratio0.15.npy')


cora_random_acc_15 = np.max(Sage_random_15)
cora_degree_acc_15 = np.max(Sage_degree_15)
cora_laplacian_acc_15 = np.max(Sage_laplacian_15) 
cora_kmedoid_acc_15 = np.max(Sage_kmedoid_15)
cora_batch_at_scale_acc_15 = np.max(Sage_batch_at_scale_15)
cora_batch_at_scale_random_acc_15 = np.max(Sage_batch_at_scale_random_15)
cora_batch_at_scale_round_robin_acc_15 = np.max(Sage_batch_at_scale_round_robin_15)
cora_Grain_ball_15 = np.max(Sage_Grain_ball_15)
cora_Grain_NND_15 = np.max(Sage_Grain_NND_15)

# %%
ratio = np.array([0.03, 0.05, 0.06, 0.07, 0.08, 0.09, 0.10, 0.15])

Random_acc = np.array([cora_random_acc_03, cora_random_acc_05, cora_random_acc_06, cora_random_acc_07, cora_random_acc_08,
              cora_random_acc_09, cora_random_acc_10, cora_random_acc_15])
Degree_acc = np.array([cora_degree_acc_03, cora_degree_acc_05, cora_degree_acc_06, cora_degree_acc_07, cora_degree_acc_08,
              cora_degree_acc_09, cora_degree_acc_10, cora_degree_acc_15])
Laplacian_acc = np.array([cora_laplacian_acc_03, cora_laplacian_acc_05, cora_laplacian_acc_06, cora_laplacian_acc_07, 
                 cora_laplacian_acc_08, cora_laplacian_acc_09, cora_laplacian_acc_10, cora_laplacian_acc_15])
FeatProp_acc = np.array([cora_kmedoid_acc_03, cora_kmedoid_acc_05, cora_kmedoid_acc_06, cora_kmedoid_acc_07, cora_kmedoid_acc_08,
                cora_kmedoid_acc_09, cora_kmedoid_acc_10, cora_kmedoid_acc_15])
Grain_ball_acc = np.array([cora_Grain_ball_03, cora_Grain_ball_05, cora_Grain_ball_06, cora_Grain_ball_07, cora_Grain_ball_08, 
                  cora_Grain_ball_09, cora_Grain_ball_10, cora_Grain_ball_15])
Grain_NND_acc = np.array([cora_Grain_NND_03, cora_Grain_NND_05, cora_Grain_NND_06, cora_Grain_NND_07, cora_Grain_NND_08, 
                 cora_Grain_NND_09, cora_Grain_NND_10, cora_Grain_NND_15])
GIDUS_acc = np.array([cora_batch_at_scale_acc_03, cora_batch_at_scale_acc_05, cora_batch_at_scale_acc_06, 
             cora_batch_at_scale_acc_07, cora_batch_at_scale_acc_08, cora_batch_at_scale_acc_09, 
             cora_batch_at_scale_acc_10, cora_batch_at_scale_acc_15])


index = [1, 3, 5, 7]

plt.plot(ratio[index], Random_acc[index], label="Random", marker = "o", markersize=5)
plt.plot(ratio[index], Degree_acc[index], label="Degree", marker = "o", markersize=5)
plt.plot(ratio[index], Laplacian_acc[index], label="Laplacian", marker = "o", markersize=5)
plt.plot(ratio[index], FeatProp_acc[index], label="FeatProp", marker = "o", markersize=5)
plt.plot(ratio[index], Grain_ball_acc[index], label="Grain(ball-D)", marker = "o", markersize=5)
plt.plot(ratio[index], Grain_NND_acc[index], label="Grain(NND)", marker = "o", markersize=5)
plt.plot(ratio[index], GIDUS_acc[index], label="ScatterSample", marker = "o", markersize=5)
plt.legend()
plt.show()

# %%
row_1 = np.array([cora_acc_256, cora_random_acc_03, cora_degree_acc_03, cora_laplacian_acc_03, cora_kmedoid_acc_03, 
                  cora_Grain_ball_03, cora_Grain_ball_03, cora_batch_at_scale_acc_03])
row_2 = np.array([cora_acc_256, cora_random_acc_05, cora_degree_acc_05, cora_laplacian_acc_05, cora_kmedoid_acc_05, 
                  cora_Grain_ball_05, cora_Grain_ball_05,cora_batch_at_scale_acc_05])
row_3 = np.array([cora_acc_256, cora_random_acc_10, cora_degree_acc_10, cora_laplacian_acc_10, cora_kmedoid_acc_10, 
                  cora_Grain_ball_10, cora_Grain_ball_10, cora_batch_at_scale_acc_10])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["cora, ratio=0.03", "cora, ratio=0.05", "cora, ratio=0.1"]
names = ["Standard", "Random", "Degree", "Laplacian", "FeatProp (2-layer)", "Grain_ball", "Grain_NND", "Uncertain+Cluster"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
display(df)



row_1 = np.array([cora_batch_at_scale_acc_03, cora_batch_at_scale_random_acc_03, cora_batch_at_scale_round_robin_acc_03,
                 cora_batch_at_scale_cluster_input_acc_03, cora_batch_at_scale_cluster_embed_acc_03])
row_2 = np.array([cora_batch_at_scale_acc_05, cora_batch_at_scale_random_acc_05, 
                  cora_batch_at_scale_round_robin_acc_05, cora_batch_at_scale_cluster_input_acc_05,
                 cora_batch_at_scale_cluster_embed_acc_05])
row_3 = np.array([cora_batch_at_scale_acc_10, cora_batch_at_scale_random_acc_10, 
                  cora_batch_at_scale_round_robin_acc_10, cora_batch_at_scale_cluster_input_acc_10,
                 cora_batch_at_scale_cluster_embed_acc_10])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["cora, ratio=0.03", "cora, ratio=0.05", "cora, ratio=0.1"]
names = ["GIDUS (kmeans++)", "GIDUS (random)", "GIDUS (round robin)", "GIDUS (cluster input)", "GIDUS (cluster embed)"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
display(df)
# Out:
#                   Standard  Random  Degree  Laplacian  FeatProp (2-layer)  \
# cora, ratio=0.03     0.876   0.564   0.573      0.552               0.549
# cora, ratio=0.05     0.876   0.678   0.675      0.597               0.656
# cora, ratio=0.1      0.876   0.757   0.744      0.692               0.724
#
#                   Grain_ball  Grain_NND  Uncertain+Cluster
# cora, ratio=0.03       0.715      0.715              0.549
# cora, ratio=0.05       0.746      0.746              0.753
# cora, ratio=0.1        0.768      0.768              0.805
#                   GIDUS (kmeans++)  GIDUS (random)  GIDUS (round robin)  \
# cora, ratio=0.03             0.549           0.549                0.549
# cora, ratio=0.05             0.753           0.748                0.752
# cora, ratio=0.1              0.805           0.786                0.795
#
#                   GIDUS (cluster input)  GIDUS (cluster embed)
# cora, ratio=0.03                  0.549                  0.549
# ...

# %% [markdown]
# ## Pubmed Dataset

# %%
Sage_183 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_batchsize183.npy')
Sage_random_01 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_random_ratio0.01.npy')
Sage_degree_01 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_degree_ratio0.01.npy')
Sage_laplacian_01 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_laplacian_ratio0.01.npy')
Sage_kmedoid_01 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_Kmedoid_ncluster182_AggregateLayer3_ratio0.01.npy')
Sage_random_loss_01 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_EL2N_sample_pretrain100_epochs1000_pretrain_ratio0.01_ratio0.01_sample_freq20.npy')
Sage_gradient_01 = np.load('./pubmed/GraphSage_macro_f1_list_pubmed_large_gradient_ratio0.01.npy')
Sage_Grain_ball_01 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_GRAIN_ball_ratio0.01.npy')
Sage_Grain_NND_01 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_GRAIN_NND_ratio0.01.npy')

pubmed_acc_183 = np.max(Sage_183)
pubmed_random_acc_01 = np.max(Sage_random_01)
pubmed_degree_acc_01 = np.max(Sage_degree_01)
pubmed_laplacian_acc_01 = np.max(Sage_laplacian_01) 
pubmed_kmedoid_acc_01 = np.max(Sage_kmedoid_01)
pubmed_random_loss_acc_01 = np.max(Sage_random_loss_01)
pubmed_gradient_acc_01 = np.max(Sage_gradient_01)
pubmed_batch_at_scale_acc_01 = pubmed_kmedoid_acc_01
pubmed_batch_at_scale_random_acc_01 = pubmed_kmedoid_acc_01
pubmed_batch_at_scale_round_robin_acc_01 = pubmed_kmedoid_acc_01
pubmed_batch_at_scale_cluster_input_acc_01 = pubmed_kmedoid_acc_01
pubmed_batch_at_scale_cluster_embed_acc_01 = pubmed_kmedoid_acc_01
pubmed_Grain_ball_acc_01 = np.max(Sage_Grain_ball_01)
pubmed_Grain_NND_acc_01 = np.max(Sage_Grain_NND_01)

Sage_random_05 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_random_ratio0.05.npy')
Sage_degree_05 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_degree_ratio0.05.npy')
Sage_laplacian_05 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_laplacian_ratio0.05.npy')
Sage_kmedoid_05 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_Kmedoid_ncluster200_AggregateLayer3_ratio0.05.npy')
Sage_random_loss_05 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_EL2N_sample_pretrain100_epochs600_pretrain_ratio0.05_ratio0.01_sample_freq30.npy')
Sage_gradient_05 = np.load('./pubmed/GraphSage_macro_f1_list_pubmed_large_gradient_ratio0.05.npy')
Sage_batch_at_scale_05 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_batch_at_scale_pretrain_ratio0.01_ratio0.002_total_ratio0.05.npy')
Sage_batch_at_scale_random_05 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_batch_at_scale_sample_method_random_choice_cold_startFalse_redundancy20_pretrain_ratio0.01_ratio0.005_total_ratio0.05.npy')
Sage_batch_at_scale_round_robin_05 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy20_pretrain_ratio0.01_ratio0.005_total_ratio0.05.npy')
Sage_batch_at_scale_cluster_input_05 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_batch_at_scale_sample_method_cluster_input_cold_startFalse_redundancy20_pretrain_ratio0.01_ratio0.005_total_ratio0.05.npy')
Sage_batch_at_scale_cluster_embed_05 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_batch_at_scale_sample_method_cluster_embed_cold_startFalse_redundancy20_pretrain_ratio0.01_ratio0.005_total_ratio0.05.npy')
Sage_Grain_ball_05 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_GRAIN_ball_ratio0.05.npy')
Sage_Grain_NND_05 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_GRAIN_NND_ratio0.05.npy')


pubmed_random_acc_05 = np.max(Sage_random_05)
pubmed_degree_acc_05 = np.max(Sage_degree_05)
pubmed_laplacian_acc_05 = np.max(Sage_laplacian_05) 
pubmed_kmedoid_acc_05 = np.max(Sage_kmedoid_05)
pubmed_random_loss_acc_05 = np.max(Sage_random_loss_05)
pubmed_gradient_acc_05 = np.max(Sage_gradient_05)
pubmed_batch_at_scale_acc_05 = np.max(Sage_batch_at_scale_05)
pubmed_batch_at_scale_random_acc_05 = np.max(Sage_batch_at_scale_random_05)
pubmed_batch_at_scale_round_robin_acc_05 = np.max(Sage_batch_at_scale_round_robin_05)
pubmed_batch_at_scale_cluster_input_acc_05 = np.max(Sage_batch_at_scale_cluster_input_05)
pubmed_batch_at_scale_cluster_embed_acc_05 = np.max(Sage_batch_at_scale_cluster_embed_05)
pubmed_Grain_ball_acc_05 = np.max(Sage_Grain_ball_05)
pubmed_Grain_NND_acc_05 = np.max(Sage_Grain_NND_05)

# %%
Sage_256 = np.load('./pubmed/GraphSage_accuracy_list_pubmed.npy')
Sage_random_10 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_random_ratio0.1.npy')
Sage_laplacian_10 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_laplacian_ratio0.1.npy')
Sage_degree_10 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_degree_ratio0.1.npy')
Sage_kmedoid_10 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_Kmedoid_ncluster200_AggregateLayer3_ratio0.1.npy')
Sage_batch_at_scale_10 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_batch_at_scale_pretrain_ratio0.01_ratio0.002_total_ratio0.1.npy')
Sage_batch_at_scale_random_10 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_batch_at_scale_sample_method_random_choice_cold_startFalse_redundancy20_pretrain_ratio0.01_ratio0.002_total_ratio0.1.npy')
Sage_batch_at_scale_round_robin_10 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy20_pretrain_ratio0.01_ratio0.002_total_ratio0.1.npy')
Sage_batch_at_scale_cluster_input_10 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_batch_at_scale_sample_method_cluster_input_cold_startFalse_redundancy20_pretrain_ratio0.01_ratio0.002_total_ratio0.1.npy')
Sage_batch_at_scale_cluster_embed_10 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_batch_at_scale_sample_method_cluster_embed_cold_startFalse_redundancy20_pretrain_ratio0.01_ratio0.002_total_ratio0.1.npy')
Sage_Grain_ball_10 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_GRAIN_ball_ratio0.1.npy')
Sage_Grain_NND_10 = np.load('./pubmed/GraphSage_accuracy_list_pubmed_GRAIN_NND_ratio0.1.npy')


pubmed_acc_256 = np.max(Sage_256)
pubmed_random_acc_10 = np.max(Sage_random_10)
pubmed_laplacian_acc_10 = np.max(Sage_laplacian_10)
pubmed_degree_acc_10 = np.max(Sage_degree_10)
pubmed_kmedoid_acc_10 = np.max(Sage_kmedoid_10) 
pubmed_batch_at_scale_acc_10 = np.max(Sage_batch_at_scale_10)
pubmed_batch_at_scale_random_acc_10 = np.max(Sage_batch_at_scale_random_10)
pubmed_batch_at_scale_round_robin_acc_10 = np.max(Sage_batch_at_scale_round_robin_10)
pubmed_batch_at_scale_cluster_input_acc_10 = np.max(Sage_batch_at_scale_cluster_input_10)
pubmed_batch_at_scale_cluster_embed_acc_10 = np.max(Sage_batch_at_scale_cluster_embed_10)
pubmed_Grain_ball_acc_10 = np.max(Sage_Grain_ball_10)
pubmed_Grain_NND_acc_10 = np.max(Sage_Grain_NND_10)


# Sage_uncertain = np.load('./pubmed/GraphSage_accuracy_list_pubmed_active_random_uncertain_epochs600_pretrain100_ratio0.1_sample_freq20.npy')
# Sage_uncertain_incre = np.load('./pubmed/GraphSage_accuracy_list_pubmed_active_random_uncertain_increment_pretrain100_epochs600_pretrain_ratio0.1_ratio0.01_sample_freq20.npy')
# Sage_uncertain_kick = np.load('./pubmed/GraphSage_accuracy_list_pubmed_active_random_uncertain_kick_out_pretrain100_epochs600_pretrain_ratio0.1_ratio0.01_sample_freq20.npy')
# Sage_gradient_10 = np.load('./pubmed/GraphSage_macro_f1_list_pubmed_large_gradient_ratio0.1.npy')
# Sage_EL2N_incre = np.load('./pubmed/GraphSage_accuracy_list_pubmed_active_random_EL2N_increment_pretrain100_epochs600_pretrain_ratio0.1_ratio0.01_sample_freq20.npy')
# Sage_EL2N_kick = np.load('./pubmed/GraphSage_accuracy_list_pubmed_active_random_EL2N_kick_out_pretrain100_epochs600_pretrain_ratio0.1_ratio0.01_sample_freq20.npy')

# pubmed_gradient_acc_10 = np.max(Sage_gradient_10)
# pubmed_uncertain_acc = np.max(Sage_uncertain)
# pubmed_uncertain_incre_acc = np.max(Sage_uncertain_incre)
# pubmed_uncertain_kick_acc = np.max(Sage_uncertain_kick)
# pubmed_EL2N_incre_acc = np.max(Sage_EL2N_incre)
# pubmed_EL2N_kick_acc = np.max(Sage_EL2N_kick)

# %%
row_1 = np.array([pubmed_acc_256, pubmed_random_acc_01, pubmed_degree_acc_01, pubmed_laplacian_acc_01, 
                  pubmed_kmedoid_acc_01, pubmed_Grain_ball_acc_01, pubmed_Grain_NND_acc_01, pubmed_batch_at_scale_acc_01])
row_2 = np.array([pubmed_acc_256, pubmed_random_acc_05, pubmed_degree_acc_05, pubmed_laplacian_acc_05, 
                  pubmed_kmedoid_acc_05, pubmed_Grain_ball_acc_05, pubmed_Grain_NND_acc_05, pubmed_batch_at_scale_acc_05])
row_3 = np.array([pubmed_acc_256, pubmed_random_acc_10, pubmed_degree_acc_10, pubmed_laplacian_acc_10, 
                  pubmed_kmedoid_acc_10, pubmed_Grain_ball_acc_10, pubmed_Grain_NND_acc_10, pubmed_batch_at_scale_acc_10])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["Pubmed, ratio=0.01", "Pubmed, ratio=0.05", "Pubmed, ratio=0.1"]
names = ["Standard", "Random", "Degree", "Laplacian", "FeatProp (2-layer)", "Grain_ball", "Grain_NND", "Uncertain+Cluster"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
display(df)



row_1 = np.array([pubmed_batch_at_scale_acc_01, pubmed_batch_at_scale_random_acc_01, 
                  pubmed_batch_at_scale_round_robin_acc_01, pubmed_batch_at_scale_cluster_input_acc_01,
                 pubmed_batch_at_scale_cluster_embed_acc_01])
row_2 = np.array([pubmed_batch_at_scale_acc_05, pubmed_batch_at_scale_random_acc_05, 
                  pubmed_batch_at_scale_round_robin_acc_05, pubmed_batch_at_scale_cluster_input_acc_05,
                 pubmed_batch_at_scale_cluster_embed_acc_05])
row_3 = np.array([pubmed_batch_at_scale_acc_10, pubmed_batch_at_scale_random_acc_10, 
                  pubmed_batch_at_scale_round_robin_acc_10, pubmed_batch_at_scale_cluster_input_acc_10,
                 pubmed_batch_at_scale_cluster_embed_acc_10])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["pubmed, ratio=0.03", "pubmed, ratio=0.05", "pubmed, ratio=0.1"]
names = ["GIDUS (kmeans++)", "GIDUS (random)", "GIDUS (round robin)", "GIDUS (cluster input)", "GIDUS (cluster embed)"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
display(df)
# Out:
#                     Standard  Random  Degree  Laplacian  FeatProp (2-layer)  \
# Pubmed, ratio=0.01     0.903   0.790   0.735      0.685               0.830
# Pubmed, ratio=0.05     0.903   0.853   0.835      0.848               0.843
# Pubmed, ratio=0.1      0.903   0.867   0.862      0.864               0.877
#
#                     Grain_ball  Grain_NND  Uncertain+Cluster
# Pubmed, ratio=0.01       0.825      0.817              0.830
# Pubmed, ratio=0.05       0.859      0.858              0.872
# Pubmed, ratio=0.1        0.861      0.872              0.888
#                     GIDUS (kmeans++)  GIDUS (random)  GIDUS (round robin)  \
# pubmed, ratio=0.03             0.830           0.830                0.830
# pubmed, ratio=0.05             0.872           0.862                0.868
# pubmed, ratio=0.1              0.888           0.886                0.885
#
#                     GIDUS (cluster input)  GIDUS (cluster embed)
# ...

# %% [markdown]
# ## CoraFull

# %%
Sage_256 = np.load('./corafull/GraphSage_accuracy_list_corafull_batchsize256.npy')
corafull_acc_256 = np.max(Sage_256)

Sage_random_03 = np.load("./corafull/GraphSage_accuracy_list_corafull_random_ratio0.03.npy")
Sage_laplacian_03 = np.load("./corafull/GraphSage_accuracy_list_corafull_laplacian_ratio0.03.npy")
Sage_degree_03 = np.load("./corafull/GraphSage_accuracy_list_corafull_degree_ratio0.03.npy")
Sage_kmedoid_03 = np.load("./corafull/GraphSage_accuracy_list_corafull_Kmedoid_ncluster200_PropToSdFalse_AggregateLayer2_ratio0.03.npy")
Sage_Grain_ball_03 = np.load("./corafull/GraphSage_accuracy_list_corafull_GRAIN_ball_ratio0.03.npy")
Sage_Grain_NND_03 = np.load("./corafull/GraphSage_accuracy_list_corafull_GRAIN_NND_ratio0.03.npy")
Sage_label_cluster_03 = np.load("./corafull/GraphSage_accuracy_list_corafull_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy30_pretrain_ratio0.01_ratio0.005_total_ratio0.03.npy")

corafull_random_acc_03 = np.max(Sage_random_03)
corafull_laplacian_acc_03 = np.max(Sage_laplacian_03)
corafull_degree_acc_03 = np.max(Sage_degree_03)
corafull_kmedoid_acc_03 = np.max(Sage_kmedoid_03)
corafull_batch_at_scale_acc_03 = np.max(Sage_label_cluster_03)
corafull_Grain_ball_acc_03 = np.max(Sage_Grain_ball_03)
corafull_Grain_NND_acc_03 = np.max(Sage_Grain_NND_03)



Sage_random_05 = np.load("./corafull/GraphSage_accuracy_list_corafull_random_ratio0.05.npy")
Sage_laplacian_05 = np.load("./corafull/GraphSage_accuracy_list_corafull_laplacian_ratio0.05.npy")
Sage_degree_05 = np.load("./corafull/GraphSage_accuracy_list_corafull_degree_ratio0.05.npy")
Sage_kmedoid_05 = np.load("./corafull/GraphSage_accuracy_list_corafull_Kmedoid_ncluster200_PropToSdFalse_AggregateLayer2_ratio0.05.npy")
Sage_Grain_ball_05 = np.load("./corafull/GraphSage_accuracy_list_corafull_GRAIN_ball_ratio0.05.npy")
Sage_Grain_NND_05 = np.load("./corafull/GraphSage_accuracy_list_corafull_GRAIN_NND_ratio0.05.npy")
Sage_label_cluster_05 = np.load("./corafull/GraphSage_accuracy_list_corafull_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy20_pretrain_ratio0.01_ratio0.005_total_ratio0.05.npy")

corafull_random_acc_05 = np.max(Sage_random_05)
corafull_laplacian_acc_05 = np.max(Sage_laplacian_05)
corafull_degree_acc_05 = np.max(Sage_degree_05)
corafull_kmedoid_acc_05 = np.max(Sage_kmedoid_05)
corafull_batch_at_scale_acc_05 = np.max(Sage_label_cluster_05)
corafull_Grain_ball_acc_05 = np.max(Sage_Grain_ball_05)
corafull_Grain_NND_acc_05 = np.max(Sage_Grain_NND_05)



Sage_random_10 = np.load("./corafull/GraphSage_accuracy_list_corafull_random_ratio0.1.npy")
Sage_laplacian_10 = np.load("./corafull/GraphSage_accuracy_list_corafull_laplacian_ratio0.1.npy")
Sage_degree_10 = np.load("./corafull/GraphSage_accuracy_list_corafull_degree_ratio0.1.npy")
Sage_kmedoid_10 = np.load("./corafull/GraphSage_accuracy_list_corafull_Kmedoid_ncluster200_PropToSdFalse_AggregateLayer2_ratio0.1.npy")
Sage_Grain_ball_10 = np.load("./corafull/GraphSage_accuracy_list_corafull_GRAIN_ball_ratio0.1.npy")
Sage_Grain_NND_10 = np.load("./corafull/GraphSage_accuracy_list_corafull_GRAIN_NND_ratio0.1.npy")
Sage_label_cluster_10 = np.load("./corafull/GraphSage_accuracy_list_corafull_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy30_pretrain_ratio0.01_ratio0.005_total_ratio0.1.npy")

corafull_random_acc_10 = np.max(Sage_random_10)
corafull_laplacian_acc_10 = np.max(Sage_laplacian_10)
corafull_degree_acc_10 = np.max(Sage_degree_10)
corafull_kmedoid_acc_10 = np.max(Sage_kmedoid_10)
corafull_batch_at_scale_acc_10 = np.max(Sage_label_cluster_10)
corafull_Grain_ball_acc_10 = np.max(Sage_Grain_ball_10)
corafull_Grain_NND_acc_10 = np.max(Sage_Grain_NND_10)

# %%
row_1 = np.array([corafull_acc_256, corafull_random_acc_03, corafull_degree_acc_03, corafull_laplacian_acc_03, 
                  corafull_kmedoid_acc_03, corafull_Grain_ball_acc_03, corafull_Grain_NND_acc_03, corafull_batch_at_scale_acc_03])
row_2 = np.array([corafull_acc_256, corafull_random_acc_05, corafull_degree_acc_05, corafull_laplacian_acc_05, 
                  corafull_kmedoid_acc_05, corafull_Grain_ball_acc_05, corafull_Grain_NND_acc_05, corafull_batch_at_scale_acc_05])
row_3 = np.array([corafull_acc_256, corafull_random_acc_10, corafull_degree_acc_10, corafull_laplacian_acc_10, 
                  corafull_kmedoid_acc_10, corafull_Grain_ball_acc_10, corafull_Grain_NND_acc_10, corafull_batch_at_scale_acc_10])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["corafull, ratio=0.03", "corafull, ratio=0.05", "corafull, ratio=0.1"]
names = ["Standard", "Random", "Degree", "Laplacian", "FeatProp (2-layer)", "Grain_ball", "Grain_NND", "Uncertain+Cluster"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
# Out:
#                       Standard  Random  Degree  Laplacian  FeatProp (2-layer)  \
# corafull, ratio=0.03     0.742   0.527   0.433      0.362               0.556
# corafull, ratio=0.05     0.742   0.573   0.489      0.428               0.585
# corafull, ratio=0.1      0.742   0.630   0.587      0.547               0.650
#
#                       Grain_ball  Grain_NND  Uncertain+Cluster
# corafull, ratio=0.03       0.571      0.563              0.571
# corafull, ratio=0.05       0.608      0.610              0.627
# corafull, ratio=0.1        0.641      0.662              0.670

# %% [markdown]
# ## Ogbn-products

# %%
Sage_512 = np.load("./ogbn-products/GraphSage_accuracy_list_ogbn-products_batchsize512.npy")
products_acc_512 = np.max(Sage_512)


Sage_label_cluster_003 = np.load("./ogbn-products/GraphSage_accuracy_list_ogbn-products_random_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy20_pretrain_ratio0.001_ratio0.0005_total_ratio0.003.npy")

products_batch_at_scale_acc_003 = np.max(Sage_label_cluster_003)


# Sage_random_005 = np.load("./ogbn-products/GraphSage_accuracy_list_ogbn-products_random_ratio0.005.npy")
Sage_laplacian_005 = np.load("./ogbn-products/GraphSage_accuracy_list_ogbn-products_laplacian_ratio0.005.npy")
Sage_degree_005 = np.load("./ogbn-products/GraphSage_accuracy_list_ogbn-products_degree_ratio0.005.npy")
Sage_kmedoid_005 = np.load("./ogbn-products/GraphSage_accuracy_list_ogbn-products_Kmedoid_ncluster200_PropToSdFalse_AggregateLayer2_ratio0.005.npy")
Sage_label_cluster_005 = np.load("./ogbn-products/GraphSage_accuracy_list_ogbn-products_random_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy20_pretrain_ratio0.003_ratio0.0005_total_ratio0.005.npy")

# products_random_acc_005 = np.max(Sage_random_005)
products_random_acc_005 = 0.56
products_degree_acc_005 = np.max(Sage_degree_005)
products_laplacian_acc_005 = np.max(Sage_laplacian_005)
products_kmedoid_acc_005 = np.max(Sage_kmedoid_005)
products_batch_at_scale_acc_005 = np.max(Sage_label_cluster_005)



Sage_random_008 = np.load("./ogbn-products/GraphSage_accuracy_list_ogbn-products_random_ratio0.008.npy")
Sage_laplacian_008 = np.load("./ogbn-products/GraphSage_accuracy_list_ogbn-products_laplacian_ratio0.008.npy")
Sage_degree_008 = np.load("./ogbn-products/GraphSage_accuracy_list_ogbn-products_degree_ratio0.008.npy")
Sage_kmedoid_008 = np.load("./ogbn-products/GraphSage_accuracy_list_ogbn-products_Kmedoid_ncluster200_PropToSdFalse_AggregateLayer2_ratio0.008.npy")
Sage_label_cluster_008 = np.load("./ogbn-products/GraphSage_accuracy_list_ogbn-products_random_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy40_pretrain_ratio0.003_ratio0.0005_total_ratio0.008.npy")

products_random_acc_008 = np.max(Sage_random_008)
products_degree_acc_008 = np.max(Sage_degree_008)
products_laplacian_acc_008 = np.max(Sage_laplacian_008)
products_kmedoid_acc_008 = np.max(Sage_kmedoid_008)
products_batch_at_scale_acc_008 = np.max(Sage_label_cluster_008)



Sage_random_01 = np.load("./ogbn-products/GraphSage_accuracy_list_ogbn-products_random_ratio0.01.npy")
Sage_laplacian_01 = np.load("./ogbn-products/GraphSage_accuracy_list_ogbn-products_laplacian_ratio0.01.npy")
Sage_degree_01 = np.load("./ogbn-products/GraphSage_accuracy_list_ogbn-products_degree_ratio0.01.npy")
Sage_kmedoid_01 = np.load("./ogbn-products/GraphSage_accuracy_list_ogbn-products_Kmedoid_ncluster200_PropToSdFalse_AggregateLayer2_ratio0.01.npy")
Sage_label_cluster_01 = np.load("./ogbn-products/GraphSage_accuracy_list_ogbn-products_random_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy40_pretrain_ratio0.003_ratio0.0005_total_ratio0.01.npy")

products_random_acc_01 = np.max(Sage_random_01)
products_degree_acc_01 = np.max(Sage_degree_01)
products_laplacian_acc_01 = np.max(Sage_laplacian_01)
products_kmedoid_acc_01 = np.max(Sage_kmedoid_01)
products_batch_at_scale_acc_01 = np.max(Sage_label_cluster_01)

# %%
row_1 = np.array([products_acc_512, products_random_acc_005, products_degree_acc_005, products_laplacian_acc_005, 
                  products_kmedoid_acc_005, products_batch_at_scale_acc_005])

row_2 = np.array([products_acc_512, products_random_acc_008, products_degree_acc_008, products_laplacian_acc_008, 
                  products_kmedoid_acc_008, products_batch_at_scale_acc_008])

row_3 = np.array([products_acc_512, products_random_acc_01, products_degree_acc_01, products_laplacian_acc_01, 
                  products_kmedoid_acc_01, products_batch_at_scale_acc_01])
# row_3 = np.array([products_acc_512, products_random_acc_10, products_degree_acc_10, products_laplacian_acc_10, 
#                   products_kmedoid_acc_10, products_Grain_ball_acc_10, products_Grain_NND_acc_10, products_batch_at_scale_acc_10])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["products, ratio=0.005", "products, ratio=0.008", "products, ratio=0.01"]
names = ["Standard", "Random", "Degree", "Laplacian", "FeatProp", "Uncertain+Cluster"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
# Out:
#                        Standard  Random  Degree  Laplacian  FeatProp  \
# products, ratio=0.005     0.766   0.560   0.529      0.394     0.636
# products, ratio=0.008     0.766   0.627   0.574      0.445     0.653
# products, ratio=0.01      0.766   0.634   0.585      0.462     0.655
#
#                        Uncertain+Cluster
# products, ratio=0.005              0.635
# products, ratio=0.008              0.664
# products, ratio=0.01               0.679

# %% [markdown]
# ## Obgn-arxiv

# %%
Sage_182 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_batchsize182.npy')
Sage_random_002 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_random_ratio0.002.npy')
Sage_laplacian_002 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_laplacian_ratio0.002.npy')
Sage_kmedoid_002 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_AggregateLayer3_ratio0.002.npy')
Sage_kmedoid_l2_002 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_AggregateLayer2_ratio0.002.npy')
Sage_kmedoid_l1_002 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_AggregateLayer1_ratio0.002.npy')
Sage_label_cluster_002 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_label_cluster_AggregateLayer3_ratio0.002.npy')

arxiv_acc_182 = np.max(Sage_182)
arxiv_random_acc_002 = np.max(Sage_random_002)
arxiv_laplacian_acc_002 = np.max(Sage_laplacian_002)
arxiv_kmedoid_acc_002 = np.max(Sage_kmedoid_002) 
arxiv_kmedoid_acc_l2_002 = np.max(Sage_kmedoid_l2_002)
arxiv_kmedoid_acc_l1_002 = np.max(Sage_kmedoid_l1_002)
arxiv_label_cluster_acc_002 = np.max(Sage_label_cluster_002)
arxiv_batch_at_scale_acc_002 = arxiv_kmedoid_acc_002

Sage_random_005 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_random_ratio0.005.npy')
Sage_laplacian_005 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_laplacian_ratio0.005.npy')
Sage_kmedoid_005 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_ncluster454_AggregateLayer3_ratio0.005.npy')
Sage_kmedoid_l2_005 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_AggregateLayer2_ratio0.005.npy')
Sage_kmedoid_l1_005 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_AggregateLayer1_ratio0.005.npy')
Sage_label_cluster_005 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_label_cluster_AggregateLayer3_ratio0.005.npy')
Sage_batch_at_scale_005 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_batch_at_scale_cold_startTrue_redundancy40_pretrain_ratio0.0025_ratio0.0005_total_ratio0.005.npy')

arxiv_random_acc_005 = np.max(Sage_random_005)
arxiv_laplacian_acc_005 = np.max(Sage_laplacian_005)
arxiv_kmedoid_acc_005 = np.max(Sage_kmedoid_005)
arxiv_kmedoid_acc_l2_005 = np.max(Sage_kmedoid_l2_005)
arxiv_kmedoid_acc_l1_005 = np.max(Sage_kmedoid_l1_005)
arxiv_label_cluster_acc_005 = np.max(Sage_label_cluster_005)
arxiv_batch_at_scale_acc_005 = np.max(Sage_batch_at_scale_005)

Sage_random_01 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_random_ratio0.01.npy')
Sage_laplacian_01 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_laplacian_ratio0.01.npy')
Sage_kmedoid_01 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_ncluster200_PropToSdTrue_AggregateLayer3_ratio0.01.npy')
Sage_kmedoid_l2_01 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_AggregateLayer2_ratio0.01.npy')
Sage_kmedoid_l1_01 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_AggregateLayer1_ratio0.01.npy')
Sage_label_cluster_01 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_label_cluster_AggregateLayer3_ratio0.01.npy')
Sage_batch_at_scale_01 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_batch_at_scale_cold_startTrue_redundancy40_pretrain_ratio0.0025_ratio0.0005_total_ratio0.01.npy')

arxiv_random_acc_01 = np.max(Sage_random_01)
arxiv_laplacian_acc_01 = np.max(Sage_laplacian_01)
arxiv_kmedoid_acc_01 = np.max(Sage_kmedoid_01) 
arxiv_kmedoid_acc_l2_01 = np.max(Sage_kmedoid_l2_01)
arxiv_kmedoid_acc_l1_01 = np.max(Sage_kmedoid_l1_01)
arxiv_label_cluster_acc_01 = np.max(Sage_label_cluster_01)
arxiv_batch_at_scale_acc_01 = np.max(Sage_batch_at_scale_01)

# %%
Sage_256 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv.npy')
Sage_random_05 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_random_ratio0.05.npy')
Sage_laplacian_05 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_laplacian_ratio0.05.npy')
Sage_degree_05 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_degree_ratio0.05.npy')
Sage_kmedoid_05 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_Kmedoid_ncluster100_AggregateLayer3_ratio0.05.npy')
Sage_label_cluster_05 = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_label_cluster_AggregateLayer3_ratio0.05.npy')
Sage_uncertain = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_active_random_uncertain_epochs300_pretrain10_ratio0.05_sample_freq20.npy')
Sage_uncertain_incre = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_active_random_uncertain_increment_pretrain10_epochs300_pretrain_ratio0.05_ratio0.01_sample_freq20.npy')
Sage_uncertain_kick = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_active_random_uncertain_kick_out_pretrain10_epochs300_pretrain_ratio0.05_ratio0.01_sample_freq20.npy')
Sage_EL2N_incre = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_active_random_EL2N_increment_pretrain10_epochs300_pretrain_ratio0.05_ratio0.01_sample_freq20.npy')
Sage_EL2N_kick = np.load('./ogbn_arxiv/GraphSage_accuracy_list_ogbn_arxiv_active_random_EL2N_kick_out_pretrain10_epochs300_pretrain_ratio0.05_ratio0.01_sample_freq20.npy')



arxiv_acc_256 = np.max(Sage_256)
arxiv_random_acc_05 = np.max(Sage_random_05)
arxiv_laplacian_acc_05 = np.max(Sage_laplacian_05)
arxiv_degree_acc_05 = np.max(Sage_degree_05) 
arxiv_kmedoid_acc_05 = np.max(Sage_kmedoid_05) 
arxiv_label_cluster_acc_05 = np.max(Sage_label_cluster_05)
arxiv_uncertain_acc = np.max(Sage_uncertain)
arxiv_uncertain_incre_acc = np.max(Sage_uncertain_incre)
arxiv_uncertain_kick_acc = np.max(Sage_uncertain_kick)
arxiv_EL2N_incre_acc = np.max(Sage_EL2N_incre)
arxiv_EL2N_kick_acc = np.max(Sage_EL2N_kick)

# %%
row_1 = np.array([arxiv_acc_256, arxiv_random_acc_002, arxiv_laplacian_acc_002, arxiv_kmedoid_acc_002, 
                  arxiv_label_cluster_acc_002, arxiv_batch_at_scale_acc_002])
row_2 = np.array([arxiv_acc_256, arxiv_random_acc_005, arxiv_laplacian_acc_005, arxiv_kmedoid_acc_005, 
                  arxiv_label_cluster_acc_005, arxiv_batch_at_scale_acc_005])
row_3 = np.array([arxiv_acc_256, arxiv_random_acc_01, arxiv_laplacian_acc_01, arxiv_kmedoid_acc_01, 
                  arxiv_label_cluster_acc_01, arxiv_batch_at_scale_acc_01])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["arxiv, ratio=0.002", "arxiv, ratio=0.005", "arxiv, ratio=0.01"]
names = ["Standard", "Random", "Laplacian", "FeatProp (3-layer)", "LabelProp (3-layer)", "Batch at Scale"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
# Out:
#                     Standard  Random  Laplacian  FeatProp (3-layer)  \
# arxiv, ratio=0.002     0.702   0.526      0.553               0.552
# arxiv, ratio=0.005     0.702   0.572      0.605               0.595
# arxiv, ratio=0.01      0.702   0.630      0.611               0.608
#
#                     LabelProp (3-layer)  Batch at Scale
# arxiv, ratio=0.002                0.535           0.552
# arxiv, ratio=0.005                0.564           0.585
# arxiv, ratio=0.01                 0.608           0.598

# %%
row_1 = np.array([arxiv_acc_256, arxiv_random_acc_002, arxiv_laplacian_acc_002, arxiv_kmedoid_acc_002, arxiv_label_cluster_acc_002])
row_2 = np.array([arxiv_acc_256, arxiv_random_acc_005, arxiv_laplacian_acc_005, arxiv_kmedoid_acc_005, arxiv_label_cluster_acc_005])
row_3 = np.array([arxiv_acc_256, arxiv_random_acc_01, arxiv_laplacian_acc_01, arxiv_kmedoid_acc_01, arxiv_label_cluster_acc_01])
row_4 = np.array([arxiv_acc_256, arxiv_random_acc_05, arxiv_laplacian_acc_05, arxiv_kmedoid_acc_05, arxiv_label_cluster_acc_05])


table = np.stack((row_1, row_2, row_3, row_4))
table = np.around(table, 3)
dataset = ["arxiv, ratio=0.002", "arxiv, ratio=0.005", "arxiv, ratio=0.01", "arxiv, ratio=0.05"]
names = ["Standard", "Random", "Laplacian", "FeatProp (3-layer)", "LabelProp (3-layer)"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
# Out:
#                     Standard  Random  Laplacian  FeatProp (3-layer)  \
# arxiv, ratio=0.002     0.702   0.526      0.553               0.552
# arxiv, ratio=0.005     0.702   0.572      0.605               0.595
# arxiv, ratio=0.01      0.702   0.618      0.611               0.608
# arxiv, ratio=0.05      0.702   0.656      0.659               0.653
#
#                     LabelProp (3-layer)
# arxiv, ratio=0.002                0.535
# arxiv, ratio=0.005                0.564
# arxiv, ratio=0.01                 0.608
# arxiv, ratio=0.05                 0.653

# %%
row_1 = np.array([arxiv_kmedoid_acc_002, arxiv_kmedoid_acc_l2_002, arxiv_kmedoid_acc_l1_002])
row_2 = np.array([arxiv_kmedoid_acc_005, arxiv_kmedoid_acc_l2_005, arxiv_kmedoid_acc_l1_005])
row_3 = np.array([arxiv_kmedoid_acc_01, arxiv_kmedoid_acc_l2_01, arxiv_kmedoid_acc_l1_01])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["arxiv, ratio=0.002", "arxiv, ratio=0.005", "arxiv, ratio=0.01"]
names = ["FeatProp (3-layer)", "FeatProp (2-layer)", "FeatProp (1-layer)"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
# Out:
#                     FeatProp (3-layer)  FeatProp (2-layer)  FeatProp (1-layer)
# arxiv, ratio=0.002               0.264               0.228               0.252
# arxiv, ratio=0.005               0.329               0.319               0.335
# arxiv, ratio=0.01                0.345               0.364               0.388

# %%
row_1 = np.array([pubmed_acc, pubmed_random_acc, pubmed_laplacian_acc, pubmed_degree_acc, pubmed_uncertain_acc, 
                  pubmed_uncertain_incre_acc, pubmed_uncertain_kick_acc, pubmed_EL2N_incre_acc, pubmed_EL2N_kick_acc])
row_2 = np.array([arxiv_acc, arxiv_random_acc, arxiv_laplacian_acc, arxiv_degree_acc, arxiv_uncertain_acc, 
                  arxiv_uncertain_incre_acc, arxiv_uncertain_kick_acc, arxiv_EL2N_incre_acc, arxiv_EL2N_kick_acc])

table = np.stack((row_1, row_2))
table = np.around(table, 3)
dataset = ["Pubmed", "obgn-arxiv"]
names = ["Standard", "Random", "Laplacian", "Degree", "CE", "CE_incre", "CE_kick", "EL2N_incre", "EL2N_kick",]

df = pd.DataFrame(table, columns=names, index = dataset)
# df.insert(0, "Dataset", dataset)
df.round(3)
# Out:
#             Standard  Random  Laplacian  Degree     CE  CE_incre  CE_kick  \
# Pubmed         0.903   0.881      0.875   0.862  0.893     0.888    0.874
# obgn-arxiv     0.702   0.656      0.659   0.618  0.658     0.664    0.653
#
#             EL2N_incre  EL2N_kick
# Pubmed           0.876      0.876
# obgn-arxiv       0.651      0.647
