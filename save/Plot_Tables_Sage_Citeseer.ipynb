# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Citeseer Dataset

# %%
Sage_256 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batchsize256.npy')
Sage_random_03 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_random_ratio0.03.npy')
Sage_laplacian_03 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_laplacian_ratio0.03.npy')
Sage_degree_03 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_degree_ratio0.03.npy')
Sage_kmedoid_03 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_Kmedoid_ncluster54_PropToSdFalse_AggregateLayer2_ratio0.03.npy')
Sage_Grain_ball_03 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_ball_ratio0.03.npy')
Sage_Grain_NND_03 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_NND_ratio0.03.npy')

citeseer_acc_256 = np.max(Sage_256)
citeseer_random_acc_03 = np.max(Sage_random_03)
citeseer_degree_acc_03 = np.max(Sage_degree_03)
citeseer_laplacian_acc_03 = np.max(Sage_laplacian_03) 
citeseer_kmedoid_acc_03 = np.max(Sage_kmedoid_03)
citeseer_batch_at_scale_acc_03 = citeseer_kmedoid_acc_03
citeseer_batch_at_scale_random_acc_03 = citeseer_kmedoid_acc_03
citeseer_batch_at_scale_round_robin_acc_03 = citeseer_kmedoid_acc_03
citeseer_batch_at_scale_cluster_input_acc_03 = citeseer_kmedoid_acc_03
citeseer_batch_at_scale_cluster_embed_acc_03 = citeseer_kmedoid_acc_03
citeseer_Grain_ball_acc_03 = np.max(Sage_Grain_ball_03)
citeseer_Grain_NND_acc_03 = np.max(Sage_Grain_NND_03)


Sage_random_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_random_ratio0.05.npy')
Sage_degree_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_degree_ratio0.05.npy')
Sage_laplacian_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_laplacian_ratio0.05.npy')
Sage_kmedoid_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_Kmedoid_ncluster91_PropToSdFalse_AggregateLayer2_ratio0.05.npy')
Sage_batch_at_scale_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_batch_at_scale_random_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_random_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_batch_at_scale_round_robin_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_batch_at_scale_cluster_input_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_input_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_batch_at_scale_cluster_embed_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_embed_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_Grain_ball_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_ball_ratio0.05.npy')
Sage_Grain_NND_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_NND_ratio0.05.npy')
Sage_AGE_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_AGE_ratio0.05.npy')
Sage_ANRMAB_05 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_ANRMAB_ratio0.05.npy')


citeseer_random_acc_05 = np.max(Sage_random_05)
citeseer_degree_acc_05 = np.max(Sage_degree_05)
citeseer_laplacian_acc_05 = np.max(Sage_laplacian_05) 
citeseer_kmedoid_acc_05 = np.max(Sage_kmedoid_05)
citeseer_batch_at_scale_acc_05 = np.max(Sage_batch_at_scale_05)
citeseer_batch_at_scale_random_acc_05 = np.max(Sage_batch_at_scale_random_05)
citeseer_batch_at_scale_round_robin_acc_05 = np.max(Sage_batch_at_scale_round_robin_05)
citeseer_batch_at_scale_cluster_input_acc_05 = np.max(Sage_batch_at_scale_cluster_input_05)
citeseer_batch_at_scale_cluster_embed_acc_05 = np.max(Sage_batch_at_scale_cluster_embed_05)
citeseer_Grain_ball_acc_05 = np.max(Sage_Grain_ball_05)
citeseer_Grain_NND_acc_05 = np.max(Sage_Grain_NND_05)
citeseer_Grain_AGE_05 = np.max(Sage_AGE_05)
citeseer_ANRMAB_acc_05 = np.max(Sage_ANRMAB_05)


Sage_random_07 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_random_ratio0.07.npy')
Sage_degree_07 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_degree_ratio0.07.npy')
Sage_laplacian_07 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_laplacian_ratio0.07.npy')
Sage_kmedoid_07 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_Kmedoid_ncluster127_PropToSdFalse_AggregateLayer2_ratio0.07.npy')
Sage_batch_at_scale_07 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.04_ratio0.01_total_ratio0.07.npy')
Sage_batch_at_scale_random_07 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_random_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.07.npy')
Sage_batch_at_scale_round_robin_07 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.07.npy')
Sage_batch_at_scale_cluster_input_07 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_input_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.07.npy')
Sage_batch_at_scale_cluster_embed_07 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_embed_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.07.npy')
Sage_Grain_ball_07 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_ball_ratio0.07.npy')
Sage_Grain_NND_07 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_NND_ratio0.07.npy')
Sage_AGE_07 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_AGE_ratio0.07.npy')
Sage_ANRMAB_07 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_ANRMAB_ratio0.07.npy')


citeseer_random_acc_07 = np.max(Sage_random_07)
citeseer_degree_acc_07 = np.max(Sage_degree_07)
citeseer_laplacian_acc_07 = np.max(Sage_laplacian_07) 
citeseer_kmedoid_acc_07 = np.max(Sage_kmedoid_07)
citeseer_batch_at_scale_acc_07 = np.max(Sage_batch_at_scale_07)
citeseer_batch_at_scale_random_acc_07 = np.max(Sage_batch_at_scale_random_07)
citeseer_batch_at_scale_round_robin_acc_07 = np.max(Sage_batch_at_scale_round_robin_07)
citeseer_batch_at_scale_cluster_input_acc_07 = np.max(Sage_batch_at_scale_cluster_input_07)
citeseer_batch_at_scale_cluster_embed_acc_07 = np.max(Sage_batch_at_scale_cluster_embed_07)
citeseer_Grain_ball_acc_07 = np.max(Sage_Grain_ball_07)
citeseer_Grain_NND_acc_07 = np.max(Sage_Grain_NND_07)
citeseer_Grain_AGE_07 = np.max(Sage_AGE_07)
citeseer_ANRMAB_acc_07 = np.max(Sage_ANRMAB_07)



Sage_random_09 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_random_ratio0.09.npy')
Sage_degree_09 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_degree_ratio0.09.npy')
Sage_laplacian_09 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_laplacian_ratio0.09.npy')
Sage_kmedoid_09 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_Kmedoid_ncluster164_PropToSdFalse_AggregateLayer2_ratio0.09.npy')
Sage_batch_at_scale_09 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.04_ratio0.01_total_ratio0.09.npy')
Sage_batch_at_scale_random_09 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_random_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.09.npy')
Sage_batch_at_scale_round_robin_09 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.09.npy')
Sage_batch_at_scale_cluster_input_09 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_input_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.09.npy')
Sage_batch_at_scale_cluster_embed_09 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_embed_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.09.npy')
Sage_Grain_ball_09 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_ball_ratio0.09.npy')
Sage_Grain_NND_09 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_NND_ratio0.09.npy')
Sage_AGE_09 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_AGE_ratio0.09.npy')
Sage_ANRMAB_09 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_ANRMAB_ratio0.09.npy')

citeseer_random_acc_09 = np.max(Sage_random_09)
citeseer_degree_acc_09 = np.max(Sage_degree_09)
citeseer_laplacian_acc_09 = np.max(Sage_laplacian_09) 
citeseer_kmedoid_acc_09 = np.max(Sage_kmedoid_09)
citeseer_batch_at_scale_acc_09 = np.max(Sage_batch_at_scale_09)
citeseer_batch_at_scale_random_acc_09 = np.max(Sage_batch_at_scale_random_09)
citeseer_batch_at_scale_round_robin_acc_09 = np.max(Sage_batch_at_scale_round_robin_09)
citeseer_batch_at_scale_cluster_input_acc_09 = np.max(Sage_batch_at_scale_cluster_input_09)
citeseer_batch_at_scale_cluster_embed_acc_09 = np.max(Sage_batch_at_scale_cluster_embed_09)
citeseer_Grain_ball_acc_09 = np.max(Sage_Grain_ball_09)
citeseer_Grain_NND_acc_09 = np.max(Sage_Grain_NND_09)
citeseer_Grain_AGE_09 = np.max(Sage_AGE_09)
citeseer_ANRMAB_acc_09 = np.max(Sage_ANRMAB_09)



Sage_random_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_random_ratio0.1.npy')
Sage_degree_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_degree_ratio0.1.npy')
Sage_laplacian_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_laplacian_ratio0.1.npy')
Sage_kmedoid_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_Kmedoid_ncluster182_PropToSdFalse_AggregateLayer2_ratio0.1.npy')
Sage_batch_at_scale_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.1.npy') 
Sage_batch_at_scale_random_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_random_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.1.npy')
Sage_batch_at_scale_round_robin_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.1.npy')
Sage_batch_at_scale_cluster_input_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_input_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.1.npy')
Sage_batch_at_scale_cluster_embed_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_embed_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.1.npy')
Sage_Grain_ball_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_ball_ratio0.1.npy')
Sage_Grain_NND_10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_NND_ratio0.1.npy')

citeseer_random_acc_10 = np.max(Sage_random_10)
citeseer_degree_acc_10 = np.max(Sage_degree_10)
citeseer_laplacian_acc_10 = np.max(Sage_laplacian_10) 
citeseer_kmedoid_acc_10 = np.max(Sage_kmedoid_10)
citeseer_batch_at_scale_acc_10 = np.max(Sage_batch_at_scale_10)
citeseer_batch_at_scale_random_acc_10 = np.max(Sage_batch_at_scale_random_10)
citeseer_batch_at_scale_round_robin_acc_10 = np.max(Sage_batch_at_scale_round_robin_10)
citeseer_batch_at_scale_cluster_input_acc_10 = np.max(Sage_batch_at_scale_cluster_input_10)
citeseer_batch_at_scale_cluster_embed_acc_10 = np.max(Sage_batch_at_scale_cluster_embed_10)
citeseer_Grain_ball_acc_10 = np.max(Sage_Grain_ball_10)
citeseer_Grain_NND_acc_10 = np.max(Sage_Grain_NND_10)

# %%
Sage_random_11 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_random_ratio0.11.npy')
Sage_degree_11 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_degree_ratio0.11.npy')
Sage_laplacian_11 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_laplacian_ratio0.11.npy')
Sage_kmedoid_11 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_Kmedoid_ncluster200_PropToSdFalse_AggregateLayer2_ratio0.11.npy')
Sage_batch_at_scale_11 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.11.npy') 
Sage_batch_at_scale_random_11 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_random_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.11.npy')
Sage_batch_at_scale_round_robin_11 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.11.npy')
Sage_batch_at_scale_cluster_input_11 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_input_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.11.npy')
Sage_batch_at_scale_cluster_embed_11 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_embed_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.11.npy')
Sage_Grain_ball_11 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_ball_ratio0.11.npy')
Sage_Grain_NND_11 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_NND_ratio0.11.npy')
Sage_AGE_11 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_AGE_ratio0.11.npy')
Sage_ANRMAB_11 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_ANRMAB_ratio0.11.npy')


citeseer_random_acc_11 = np.max(Sage_random_11)
citeseer_degree_acc_11 = np.max(Sage_degree_11)
citeseer_laplacian_acc_11 = np.max(Sage_laplacian_11) 
citeseer_kmedoid_acc_11 = np.max(Sage_kmedoid_11)
citeseer_batch_at_scale_acc_11 = np.max(Sage_batch_at_scale_11)
citeseer_batch_at_scale_random_acc_11 = np.max(Sage_batch_at_scale_random_11)
citeseer_batch_at_scale_round_robin_acc_11 = np.max(Sage_batch_at_scale_round_robin_11)
citeseer_batch_at_scale_cluster_input_acc_11 = np.max(Sage_batch_at_scale_cluster_input_11)
citeseer_batch_at_scale_cluster_embed_acc_11 = np.max(Sage_batch_at_scale_cluster_embed_11)
citeseer_Grain_ball_acc_11 = np.max(Sage_Grain_ball_11)
citeseer_Grain_NND_acc_11 = np.max(Sage_Grain_NND_11)
citeseer_Grain_AGE_11 = np.max(Sage_AGE_11)
citeseer_ANRMAB_acc_11 = np.max(Sage_ANRMAB_11)


Sage_random_13 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_random_ratio0.13.npy')
Sage_degree_13 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_degree_ratio0.13.npy')
Sage_laplacian_13 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_laplacian_ratio0.13.npy')
Sage_kmedoid_13 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_Kmedoid_ncluster237_PropToSdFalse_AggregateLayer2_ratio0.13.npy')
Sage_batch_at_scale_13 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.13.npy') 
Sage_batch_at_scale_random_13 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_random_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.13.npy')
Sage_batch_at_scale_round_robin_13 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.13.npy')
Sage_batch_at_scale_cluster_input_13 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_input_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.13.npy')
Sage_batch_at_scale_cluster_embed_13 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_embed_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.13.npy')
Sage_Grain_ball_13 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_ball_ratio0.13.npy')
Sage_Grain_NND_13 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_NND_ratio0.13.npy')
Sage_AGE_13 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_AGE_ratio0.13.npy')
Sage_ANRMAB_13 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_ANRMAB_ratio0.13.npy')

citeseer_random_acc_13 = np.max(Sage_random_13)
citeseer_degree_acc_13 = np.max(Sage_degree_13)
citeseer_laplacian_acc_13 = np.max(Sage_laplacian_13) 
citeseer_kmedoid_acc_13 = np.max(Sage_kmedoid_13)
citeseer_batch_at_scale_acc_13 = np.max(Sage_batch_at_scale_13)
citeseer_batch_at_scale_random_acc_13 = np.max(Sage_batch_at_scale_random_13)
citeseer_batch_at_scale_round_robin_acc_13 = np.max(Sage_batch_at_scale_round_robin_13)
citeseer_batch_at_scale_cluster_input_acc_13 = np.max(Sage_batch_at_scale_cluster_input_13)
citeseer_batch_at_scale_cluster_embed_acc_13 = np.max(Sage_batch_at_scale_cluster_embed_13)
citeseer_Grain_ball_acc_13 = np.max(Sage_Grain_ball_13)
citeseer_Grain_NND_acc_13 = np.max(Sage_Grain_NND_13)
citeseer_Grain_AGE_13 = np.max(Sage_AGE_13)
citeseer_ANRMAB_acc_13 = np.max(Sage_ANRMAB_13)



Sage_random_15 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_random_ratio0.15.npy')
Sage_degree_15 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_degree_ratio0.15.npy')
Sage_laplacian_15 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_laplacian_ratio0.15.npy')
Sage_kmedoid_15 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_Kmedoid_ncluster274_PropToSdFalse_AggregateLayer2_ratio0.15.npy')
Sage_batch_at_scale_15 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.15.npy') 
Sage_batch_at_scale_random_15 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_random_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.15.npy')
Sage_batch_at_scale_round_robin_15 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_round_robin_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.15.npy')
Sage_batch_at_scale_cluster_input_15 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_input_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.15.npy')
Sage_batch_at_scale_cluster_embed_15 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_cluster_embed_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.15.npy')
Sage_Grain_ball_15 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_ball_ratio0.15.npy')
Sage_Grain_NND_15 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_GRAIN_NND_ratio0.15.npy')
Sage_AGE_15 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_AGE_ratio0.15.npy')
Sage_ANRMAB_15 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_ANRMAB_ratio0.15.npy')

citeseer_random_acc_15 = np.max(Sage_random_15)
citeseer_degree_acc_15 = np.max(Sage_degree_15)
citeseer_laplacian_acc_15 = np.max(Sage_laplacian_15) 
citeseer_kmedoid_acc_15 = np.max(Sage_kmedoid_15)
citeseer_batch_at_scale_acc_15 = np.max(Sage_batch_at_scale_15)
citeseer_batch_at_scale_random_acc_15 = np.max(Sage_batch_at_scale_random_15)
citeseer_batch_at_scale_round_robin_acc_15 = np.max(Sage_batch_at_scale_round_robin_15)
citeseer_batch_at_scale_cluster_input_acc_15 = np.max(Sage_batch_at_scale_cluster_input_15)
citeseer_batch_at_scale_cluster_embed_acc_15 = np.max(Sage_batch_at_scale_cluster_embed_15)
citeseer_Grain_ball_acc_15 = np.max(Sage_Grain_ball_15)
citeseer_Grain_NND_acc_15 = np.max(Sage_Grain_NND_15)
citeseer_Grain_AGE_15 = np.max(Sage_AGE_15)
citeseer_ANRMAB_acc_15 = np.max(Sage_ANRMAB_15)

# %%
ratio = np.array([0.03, 0.05, 0.07, 0.09, 0.10, 0.11, 0.13, 0.15])

Random_acc = np.array([citeseer_random_acc_03, citeseer_random_acc_05, citeseer_random_acc_07, citeseer_random_acc_09, 
                       citeseer_random_acc_10, citeseer_random_acc_11, citeseer_random_acc_13, citeseer_random_acc_15])
Degree_acc = np.array([citeseer_degree_acc_03, citeseer_degree_acc_05, citeseer_degree_acc_07, citeseer_degree_acc_09, 
                       citeseer_degree_acc_10, citeseer_degree_acc_11, citeseer_degree_acc_13, citeseer_degree_acc_15])
Laplacian_acc = np.array([citeseer_laplacian_acc_03, citeseer_laplacian_acc_05, citeseer_laplacian_acc_07, 
                          citeseer_laplacian_acc_09, citeseer_laplacian_acc_10, citeseer_laplacian_acc_11, 
                          citeseer_laplacian_acc_13, citeseer_laplacian_acc_15])
FeatProp_acc = np.array([citeseer_kmedoid_acc_03, citeseer_kmedoid_acc_05, citeseer_kmedoid_acc_07, 
                         citeseer_kmedoid_acc_09, citeseer_kmedoid_acc_10, citeseer_kmedoid_acc_11, 
                         citeseer_kmedoid_acc_13, citeseer_kmedoid_acc_15])
Grain_ball_acc = np.array([citeseer_Grain_ball_acc_03, citeseer_Grain_ball_acc_05, citeseer_Grain_ball_acc_07, 
                           citeseer_Grain_ball_acc_09, citeseer_Grain_ball_acc_10, citeseer_Grain_ball_acc_11, 
                           citeseer_Grain_ball_acc_13, citeseer_Grain_ball_acc_15])
Grain_NND_acc = np.array([citeseer_Grain_NND_acc_03, citeseer_Grain_NND_acc_05, citeseer_Grain_NND_acc_07, 
                          citeseer_Grain_NND_acc_09, citeseer_Grain_NND_acc_10, citeseer_Grain_NND_acc_11, 
                          citeseer_Grain_NND_acc_13, citeseer_Grain_NND_acc_15])
GIDUS_acc = np.array([citeseer_batch_at_scale_acc_03, citeseer_batch_at_scale_acc_05, citeseer_batch_at_scale_acc_07, 
                      citeseer_batch_at_scale_acc_09, citeseer_batch_at_scale_acc_10, citeseer_batch_at_scale_acc_11, 
                      citeseer_batch_at_scale_acc_13, citeseer_batch_at_scale_acc_15])
AGE_acc = np.array([citeseer_Grain_AGE_05, citeseer_Grain_AGE_07, citeseer_Grain_AGE_09, citeseer_Grain_AGE_11, citeseer_Grain_AGE_13,
                    citeseer_Grain_AGE_15])
ANRMAB_acc = np.array([citeseer_ANRMAB_acc_05, citeseer_ANRMAB_acc_07, citeseer_ANRMAB_acc_09, citeseer_ANRMAB_acc_11, 
                       citeseer_ANRMAB_acc_13, citeseer_ANRMAB_acc_15])

index = [1, 2, 3, 5, 6, 7]

plt.plot(ratio[index], GIDUS_acc[index], label="ScatterSample", marker = "o", markersize=5)
plt.plot(ratio[index], AGE_acc, label="AGE", marker = "o", markersize=5)
plt.plot(ratio[index], ANRMAB_acc, label="ANRMAB", marker = "o", markersize=5)
plt.plot(ratio[index], Random_acc[index], label="Random", marker = "o", markersize=5)
plt.plot(ratio[index], FeatProp_acc[index], label="FeatProp", marker = "o", markersize=5)
# plt.plot(ratio[index], Laplacian_acc[index], label="Laplacian", marker = "o", markersize=5)
plt.plot(ratio[index], Grain_ball_acc[index], label="Grain(ball-D)", marker = "o", markersize=5)
plt.plot(ratio[index], Grain_NND_acc[index], label="Grain(NND)", marker = "o", markersize=5)

plt.xlabel('Sampling Ratio', fontsize = 14)
plt.ylabel('Test Accuracy', fontsize = 14)
plt.xticks([0.05, 0.07, 0.09, 0.11, 0.13, 0.15], fontsize=12)
plt.yticks(fontsize=12)
plt.legend()
plt.tight_layout()
plt.savefig("../Figure/citeseer_accuracy_comparison.png")
plt.show()

# %%
ratio = np.array([0.05, 0.07, 0.09, 0.11, 0.13, 0.15])
GIDUS = np.array([citeseer_batch_at_scale_acc_05, citeseer_batch_at_scale_acc_07, citeseer_batch_at_scale_acc_09, 
                  citeseer_batch_at_scale_acc_11, citeseer_batch_at_scale_acc_13, citeseer_batch_at_scale_acc_15])

random = np.array([citeseer_batch_at_scale_random_acc_05, citeseer_batch_at_scale_random_acc_07, 
                   citeseer_batch_at_scale_random_acc_09, citeseer_batch_at_scale_random_acc_11, 
                   citeseer_batch_at_scale_random_acc_13, citeseer_batch_at_scale_random_acc_15])

round_robin = np.array([citeseer_batch_at_scale_round_robin_acc_05, citeseer_batch_at_scale_round_robin_acc_11, 
                        citeseer_batch_at_scale_round_robin_acc_13, citeseer_batch_at_scale_round_robin_acc_07, 
                        citeseer_batch_at_scale_round_robin_acc_09, citeseer_batch_at_scale_round_robin_acc_15])

cluster_input = np.array([citeseer_batch_at_scale_cluster_input_acc_05, citeseer_batch_at_scale_cluster_input_acc_07, 
                          citeseer_batch_at_scale_cluster_input_acc_09, citeseer_batch_at_scale_cluster_input_acc_11, 
                          citeseer_batch_at_scale_cluster_input_acc_13, citeseer_batch_at_scale_cluster_input_acc_15])

cluster_embed = np.array([citeseer_batch_at_scale_cluster_embed_acc_05, citeseer_batch_at_scale_cluster_embed_acc_07, 
                          citeseer_batch_at_scale_cluster_embed_acc_09, citeseer_batch_at_scale_cluster_embed_acc_11, 
                          citeseer_batch_at_scale_cluster_embed_acc_13, citeseer_batch_at_scale_cluster_embed_acc_15])

index = [0, 1, 2, 3, 4, 5]

plt.plot(ratio[index], random[index], label="Random", marker = "o", markersize=5)
plt.plot(ratio[index], round_robin[index], label="Random Round Robin", marker = "o", markersize=5)
plt.plot(ratio[index], GIDUS[index], label="DiverseUncertainty", marker = "o", markersize=5)
plt.xlabel('Sampling Ratio', fontsize = 14)
plt.ylabel('Test Accuracy', fontsize = 14)
plt.xticks([0.05, 0.07, 0.09, 0.11, 0.13, 0.15], fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=13)
plt.tight_layout()
plt.savefig("../Figure/citeseer_compare_cluster_method.png")
plt.show()

plt.plot(ratio[index], cluster_embed[index], label="Cluster Input", marker = "o", markersize=5)
plt.plot(ratio[index], cluster_input[index], label="Cluster Embeddings", marker = "o", markersize=5)
plt.plot(ratio[index], GIDUS[index], label="Cluster Propagated Features", marker = "o", markersize=5)
plt.xlabel('Sampling Ratio', fontsize = 14)
plt.ylabel('Test Accuracy', fontsize = 14)
plt.xticks([0.05, 0.07, 0.09, 0.11, 0.13, 0.15], fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=13)
plt.tight_layout()
plt.savefig("../Figure/citeseer_compare_cluster_target.png")
plt.show()

# %% [markdown]
# ### Evaluate the effect of sampling redundancy

# %%
Sage_batch_at_scale_05_r1 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy1_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_batch_at_scale_05_r5 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy5_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_batch_at_scale_05_r10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')
Sage_batch_at_scale_05_r20 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.05.npy')


citeseer_05_r1 = np.max(Sage_batch_at_scale_05_r1)
citeseer_05_r5 = np.max(Sage_batch_at_scale_05_r5)
citeseer_05_r10 = np.max(Sage_batch_at_scale_05_r10)
citeseer_05_r20 = np.max(Sage_batch_at_scale_05_r20)



Sage_batch_at_scale_09_r1 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy1_pretrain_ratio0.04_ratio0.01_total_ratio0.09.npy')
Sage_batch_at_scale_09_r5 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy5_pretrain_ratio0.04_ratio0.01_total_ratio0.09.npy')
Sage_batch_at_scale_09_r10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.04_ratio0.01_total_ratio0.09.npy')
Sage_batch_at_scale_09_r20 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy20_pretrain_ratio0.04_ratio0.01_total_ratio0.09.npy')

citeseer_09_r1 = np.max(Sage_batch_at_scale_09_r1)
citeseer_09_r5 = np.max(Sage_batch_at_scale_09_r5)
citeseer_09_r10 = np.max(Sage_batch_at_scale_09_r10)
citeseer_09_r20 = np.max(Sage_batch_at_scale_09_r20)


Sage_batch_at_scale_11_r1 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy1_pretrain_ratio0.03_ratio0.01_total_ratio0.11.npy')
Sage_batch_at_scale_11_r5 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy5_pretrain_ratio0.03_ratio0.01_total_ratio0.11.npy')
Sage_batch_at_scale_11_r10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.11.npy')
Sage_batch_at_scale_11_r20 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.11.npy')

citeseer_11_r1 = np.max(Sage_batch_at_scale_11_r1)
citeseer_11_r5 = np.max(Sage_batch_at_scale_11_r5)
citeseer_11_r10 = np.max(Sage_batch_at_scale_11_r10)
citeseer_11_r20 = np.max(Sage_batch_at_scale_11_r20)


Sage_batch_at_scale_13_r1 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy1_pretrain_ratio0.03_ratio0.01_total_ratio0.13.npy')
Sage_batch_at_scale_13_r5 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy5_pretrain_ratio0.03_ratio0.01_total_ratio0.13.npy')
Sage_batch_at_scale_13_r10 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy10_pretrain_ratio0.03_ratio0.01_total_ratio0.13.npy')
Sage_batch_at_scale_13_r20 = np.load('./citeseer/GraphSage_accuracy_list_citeseer_batch_at_scale_sample_method_kmeans_cold_startFalse_redundancy20_pretrain_ratio0.03_ratio0.01_total_ratio0.13.npy')

citeseer_13_r1 = np.max(Sage_batch_at_scale_13_r1)
citeseer_13_r5 = np.max(Sage_batch_at_scale_13_r5)
citeseer_13_r10 = np.max(Sage_batch_at_scale_13_r10)
citeseer_13_r20 = np.max(Sage_batch_at_scale_13_r20)

# %%
r_list = [1, 5, 10, 20]

citeseer_05 = [citeseer_05_r1, citeseer_05_r5, citeseer_05_r10, citeseer_05_r20]
citeseer_09 = [citeseer_09_r1, citeseer_09_r5, citeseer_09_r10, citeseer_09_r20]
citeseer_11 = [citeseer_11_r1, citeseer_11_r5, citeseer_11_r10, citeseer_11_r20]
citeseer_13 = [citeseer_13_r1, citeseer_13_r5, citeseer_13_r10, citeseer_13_r20]


plt.plot(r_list, citeseer_05, marker = "o", label="Sample Ratio = 5%")
plt.plot(r_list, citeseer_09, marker = "o", label="Sample Ratio = 9%")
plt.plot(r_list, citeseer_11, marker = "o", label="Sample Ratio = 11%")
plt.plot(r_list, citeseer_13, marker = "o", label="Sample Ratio = 13%")

plt.xlabel('Sampling Redundancy', fontsize = 14)
plt.ylabel('Test Accuracy', fontsize = 14)
plt.xticks(r_list, fontsize=12)
plt.yticks(fontsize=12)
plt.legend()
plt.savefig("../Figure/citeseer_sample_redundancy.png")
plt.show()

# %%
row_1 = np.array([citeseer_acc_256, citeseer_random_acc_03, citeseer_degree_acc_03, citeseer_laplacian_acc_03, 
                  citeseer_kmedoid_acc_03, citeseer_Grain_ball_acc_03, citeseer_Grain_NND_acc_03,
                  citeseer_batch_at_scale_acc_03])
row_2 = np.array([citeseer_acc_256, citeseer_random_acc_05, citeseer_degree_acc_05, citeseer_laplacian_acc_05, 
                  citeseer_kmedoid_acc_05, citeseer_Grain_ball_acc_05, citeseer_Grain_NND_acc_05,
                  citeseer_batch_at_scale_acc_05])
row_3 = np.array([citeseer_acc_256, citeseer_random_acc_10, citeseer_degree_acc_10, citeseer_laplacian_acc_10, 
                  citeseer_kmedoid_acc_10, citeseer_Grain_ball_acc_10, citeseer_Grain_NND_acc_10,
                  citeseer_batch_at_scale_acc_10])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["citeseer, ratio=0.03", "citeseer, ratio=0.05", "citeseer, ratio=0.1"]
names = ["Standard", "Random", "Degree", "Laplacian", "FeatProp (2-layer)", "Grain_ball", "Grain_NND", "GIDUS"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
display(df)


row_1 = np.array([citeseer_batch_at_scale_acc_03, citeseer_batch_at_scale_random_acc_03, citeseer_batch_at_scale_round_robin_acc_03,
                 citeseer_batch_at_scale_cluster_input_acc_03, citeseer_batch_at_scale_cluster_embed_acc_03])
row_2 = np.array([citeseer_batch_at_scale_acc_05, citeseer_batch_at_scale_random_acc_05, citeseer_batch_at_scale_round_robin_acc_05, 
                  citeseer_batch_at_scale_cluster_input_acc_05, citeseer_batch_at_scale_cluster_embed_acc_05])
row_3 = np.array([citeseer_batch_at_scale_acc_10, citeseer_batch_at_scale_random_acc_10, citeseer_batch_at_scale_round_robin_acc_10, 
                  citeseer_batch_at_scale_cluster_input_acc_10, citeseer_batch_at_scale_cluster_embed_acc_10])

table = np.stack((row_1, row_2, row_3))
table = np.around(table, 3)
dataset = ["citeseer, ratio=0.03", "citeseer, ratio=0.05", "citeseer, ratio=0.1"]
names = ["GIDUS (kmeans++)", "GIDUS (random)", "GIDUS (round robin)", "GIDUS (cluster input)", "GIDUS (cluster embed)"]

df = pd.DataFrame(table, columns=names, index = dataset)
df.round(3)
display(df)
# Out:
#                       Standard  Random  Degree  Laplacian  FeatProp (2-layer)  \
# citeseer, ratio=0.03     0.803   0.589   0.395      0.324               0.592
# citeseer, ratio=0.05     0.803   0.626   0.471      0.639               0.620
# citeseer, ratio=0.1      0.803   0.685   0.638      0.698               0.670
#
#                       Grain_ball  Grain_NND  GIDUS
# citeseer, ratio=0.03       0.619      0.619  0.592
# citeseer, ratio=0.05       0.680      0.688  0.709
# citeseer, ratio=0.1        0.715      0.720  0.736
#                       GIDUS (kmeans++)  GIDUS (random)  GIDUS (round robin)  \
# citeseer, ratio=0.03             0.592           0.592                0.592
# citeseer, ratio=0.05             0.709           0.699                0.689
# citeseer, ratio=0.1              0.736           0.737                0.732
#
#                       GIDUS (cluster input)  GIDUS (cluster embed)
# citeseer, ratio=0.03                  0.592                  0.592
# ...
