# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Max loss measure

# %%
LADIES = np.load('test_accuracy_list_ogbn_arxiv_LADIES.npy')[0:25]
LADIES_laplacian_05 = np.load('test_accuracy_list_ogbn_arxiv_LADIES_active_laplacian_ratio0.05.npy')
LADIES_uncertain_05 = np.load('test_accuracy_ogbn_arxiv_LADIES_active_laplacian_max_loss_increment_compround800_pretrain20_ratio0.05.npy')
num_batch = 90941/256

samples_count = np.load('sample_count_ogbn_arxiv_LADIES_active_laplacian_max_loss_increment_compround800_pretrain20_ratio0.05.npy')
samples_cumsum = np.cumsum(samples_count)
num_batch_uncertain = [x/256 for x in samples_cumsum]

# %%
plt.plot(np.arange(1, len(LADIES)+1)*num_batch, LADIES, label = 'Standard')
plt.plot(np.arange(1, len(LADIES_laplacian_05)+1)*num_batch*0.05, LADIES_laplacian_05, linestyle = '--', label = 'Laplacian, 5%')
plt.plot(num_batch_uncertain, LADIES_uncertain_05, linestyle = '-.', label = 'EL2N, pretrain 5%')

plt.title('ogbn_arxiv, EL2N, ratio = 0.05', fontsize = 16)
plt.xlabel('Number of Iterations', fontsize = 14)
plt.ylabel('Accuracy', fontsize = 14)
plt.legend(fontsize = 14)
plt.ylim([0.2, 0.7])
plt.xlim([-100, 4000])
# plt.savefig('../Figure/Pubmed_accuracy_active_uncertainty_matching_comparison_ratio_0.05.png')
plt.show()

# %%
LADIES = np.load('test_accuracy_list_reddit_LADIES.npy')[0:25]
LADIES_laplacian_05 = np.load('test_accuracy_list_reddit_LADIES_active_random_ratio0.05.npy')
LADIES_uncertain_05 = np.load('test_accuracy_reddit_LADIES_active_laplacian_max_loss_increment_compround800_pretrain20_ratio0.05.npy')
num_batch = int(153431/256+1)

samples_count = np.load('sample_count_reddit_LADIES_active_laplacian_max_loss_increment_compround800_pretrain20_ratio0.05.npy')
samples_cumsum = np.cumsum(samples_count)
num_batch_uncertain = [x/256 for x in samples_cumsum]

# %%
plt.plot(np.arange(1, len(LADIES)+1)*num_batch, LADIES, label = 'Standard')
plt.plot(np.arange(1, len(LADIES_laplacian_05)+1)*(7672/256), LADIES_laplacian_05, linestyle = '--', label = 'Random, 5%')
plt.plot(num_batch_uncertain, LADIES_uncertain_05, linestyle = '-.', label = 'Max Loss, pretrain 5%')

plt.title('Reddit', fontsize = 16)
plt.xlabel('Number of Iterations', fontsize = 14)
plt.ylabel('Accuracy', fontsize = 14)
plt.legend(fontsize = 14)
plt.ylim([0.7, 0.9])
plt.xlim([-100, 3000])
# plt.savefig('../Figure/Pubmed_accuracy_active_uncertainty_matching_comparison_ratio_0.05.png')
plt.show()

# %%
LADIES = np.load('test_accuracy_list_pubmed_LADIES.npy')
LADIES_laplacian_05 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_ratio0.05.npy')
LADIES_uncertain_05 = np.load('test_accuracy_pubmed_LADIES_active_laplacian_max_loss_increment_compround800_pretrain200_ratio0.05.npy')
num_batch = int(18717/256+1)

samples_count = np.load('sample_count_pubmed_LADIES_active_laplacian_max_loss_increment_compround800_pretrain200_ratio0.05.npy')
samples_cumsum = np.cumsum(samples_count)
num_batch_uncertain = [x/256 for x in samples_cumsum]

# %%
plt.plot(np.arange(1, len(LADIES)+1)*num_batch, LADIES, label = 'Standard')
plt.plot(np.arange(1, len(LADIES_laplacian_05)+1)*(1196/256), LADIES_laplacian_05, linestyle = '--', label = 'Laplacian, 5%')
plt.plot(num_batch_uncertain, LADIES_uncertain_05, linestyle = '-.', label = 'Max Loss, pretrain 5%')

plt.title('Pubmed', fontsize = 16)
plt.xlabel('Number of Iterations', fontsize = 14)
plt.ylabel('Accuracy', fontsize = 14)
plt.legend(fontsize = 14)
plt.ylim([0.7, 0.9])
plt.xlim([100, 3000])
# plt.savefig('../Figure/Pubmed_accuracy_active_uncertainty_matching_comparison_ratio_0.05.png')
plt.show()

# %%
LADIES = np.load('test_accuracy_list_pubmed_LADIES.npy')
LADIES_laplacian_01 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_ratio0.01.npy')
LADIES_uncertain_01 = np.load('test_accuracy_pubmed_LADIES_active_laplacian_uncertain_increment_compround800_pretrain200_ratio0.01.npy')
num_batch = int(18717/256+1)

samples_count = np.load('sample_count_pubmed_LADIES_active_laplacian_uncertain_increment_compround800_pretrain200_ratio0.01.npy')
samples_cumsum = np.cumsum(samples_count)
num_batch_uncertain = [x/256 for x in samples_cumsum]

# %%
plt.plot(np.arange(len(LADIES))*num_batch, LADIES, label = 'Standard')
plt.plot(np.arange(len(LADIES_laplacian_01))*(samples_count[0]/256), LADIES_laplacian_01, linestyle = '--', label = 'Laplacian, 1%')
plt.plot(num_batch_uncertain, LADIES_uncertain_01, linestyle = '-.', label = 'Uncertainty, pretrain 1%')

plt.title('Pubmed', fontsize = 16)
plt.xlabel('Number of Iterations', fontsize = 14)
plt.ylabel('Accuracy', fontsize = 14)
plt.legend(fontsize = 14)
plt.ylim([0.7, 0.9])
plt.xlim([100, 3000])
plt.savefig('../Figure/Pubmed_accuracy_active_uncertainty_matching_comparison_ratio_0.01.png')
plt.show()

# %% [markdown]
# ## Effect of pre-training epochs

# %%
LADIES_uncertain_05_0 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_uncertain_pretrain0_ratio0.05.npy')
LADIES_uncertain_05_100 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_uncertain_pretrain100_ratio0.05.npy')
LADIES_uncertain_05_200 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_uncertain_pretrain200_ratio0.05.npy')
num_batch = int(18717/256+1)

# %%
plt.plot(np.arange(len(LADIES_uncertain_05_0))*num_batch*0.05, LADIES_uncertain_05_0, linestyle = '--', label = '5%, 0 epochs')
plt.plot(np.arange(len(LADIES_uncertain_05_100))*num_batch*0.05, LADIES_uncertain_05_100, linestyle = '-.', label = '5%, 100 epochs')
plt.plot(np.arange(len(LADIES_uncertain_05_200))*num_batch*0.05, LADIES_uncertain_05_200, linestyle = '-', label = '5%, 200 epochs')

plt.title('Pubmed, ratio = 0.05', fontsize = 16)
plt.xlabel('Number of Iterations', fontsize = 14)
plt.ylabel('Accuracy', fontsize = 14)
plt.legend(fontsize = 14)
plt.ylim([0.6, 0.9])
# plt.savefig('../Figure/Pubmed_accuracy_active_uncertainty_matching_comparison_ratio_0.05.png')
plt.show()

# %%
LADIES_uncertain_01_0 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_uncertain_pretrain0_ratio0.01.npy')
LADIES_uncertain_01_100 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_uncertain_pretrain100_ratio0.01.npy')
LADIES_uncertain_01_200 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_uncertain_pretrain200_ratio0.01.npy')
LADIES_uncertain_01_300 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_uncertain_pretrain300_ratio0.01.npy')
num_batch = int(18717/256+1)

# %%
plt.plot(np.arange(len(LADIES_uncertain_01_0))*1, LADIES_uncertain_01_0, linestyle = '--', label = '1%, 0 epochs')
plt.plot(np.arange(len(LADIES_uncertain_01_100))*1, LADIES_uncertain_01_100, linestyle = '-.', label = '1%, 100 epochs')
plt.plot(np.arange(len(LADIES_uncertain_01_200))*1, LADIES_uncertain_01_200, linestyle = '-', label = '1%, 200 epochs')
plt.plot(np.arange(len(LADIES_uncertain_01_300))*1, LADIES_uncertain_01_300, linestyle = ':', label = '1%, 300 epochs')

plt.title('Pubmed, ratio = 0.01', fontsize = 16)
plt.xlabel('Number of Iterations', fontsize = 14)
plt.ylabel('Accuracy', fontsize = 14)
plt.legend(fontsize = 14)
plt.ylim([0.6, 0.9])
# plt.savefig('../Figure/Pubmed_accuracy_active_uncertainty_matching_comparison_ratio_0.01.png')
plt.show()

# %% [markdown]
# ## number of rounds to compute embeddings

# %%
LADIES_uncertain_05_100 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_uncertain_compround100_pretrain200_ratio0.05.npy')
LADIES_uncertain_05_200 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_uncertain_compround200_pretrain200_ratio0.05.npy')
LADIES_uncertain_05_300 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_uncertain_compround300_pretrain200_ratio0.05.npy')
num_batch = int(18717/256+1)

# %%
plt.plot(np.arange(len(LADIES_uncertain_05_100))*num_batch*0.05, LADIES_uncertain_05_100, linestyle = '-.', label = '5%, 100 epochs')
plt.plot(np.arange(len(LADIES_uncertain_05_200))*num_batch*0.05, LADIES_uncertain_05_200, linestyle = '-', label = '5%, 200 epochs')
plt.plot(np.arange(len(LADIES_uncertain_05_300))*num_batch*0.05, LADIES_uncertain_05_300, linestyle = ':', label = '5%, 300 epochs')

plt.title('Pubmed, ratio = 0.05', fontsize = 16)
plt.xlabel('Number of Iterations', fontsize = 14)
plt.ylabel('Accuracy', fontsize = 14)
plt.legend(fontsize = 14)
plt.ylim([0.7, 0.9])
# plt.savefig('../Figure/Pubmed_accuracy_active_uncertainty_matching_comparison_ratio_0.01.png')
plt.show()

# %%
LADIES_uncertain_01_100 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_uncertain_compround100_pretrain200_ratio0.01.npy')
LADIES_uncertain_01_200 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_uncertain_compround200_pretrain200_ratio0.01.npy')
LADIES_uncertain_01_300 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_uncertain_compround300_pretrain200_ratio0.01.npy')
LADIES_uncertain_01_400 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_uncertain_compround400_pretrain200_ratio0.01.npy')
LADIES_uncertain_01_500 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_uncertain_compround500_pretrain200_ratio0.01.npy')
LADIES_uncertain_01_600 = np.load('test_accuracy_list_pubmed_LADIES_active_laplacian_uncertain_compround600_pretrain200_ratio0.01.npy')
num_batch = int(18717/256+1)

# %%
plt.plot(np.arange(len(LADIES_uncertain_01_200))*1, LADIES_uncertain_01_200, linestyle = '-.', label = '1%, 200 epochs')
plt.plot(np.arange(len(LADIES_uncertain_01_400))*1, LADIES_uncertain_01_400, linestyle = '-', label = '1%, 400 epochs')
plt.plot(np.arange(len(LADIES_uncertain_01_600))*1, LADIES_uncertain_01_600, linestyle = ':', label = '1%, 600 epochs')

plt.title('Pubmed, ratio = 0.01', fontsize = 16)
plt.xlabel('Number of Iterations', fontsize = 14)
plt.ylabel('Accuracy', fontsize = 14)
plt.legend(fontsize = 14)
plt.ylim([0.7, 0.9])
# plt.savefig('../Figure/Pubmed_accuracy_active_uncertainty_matching_comparison_ratio_0.01.png')
plt.show()
